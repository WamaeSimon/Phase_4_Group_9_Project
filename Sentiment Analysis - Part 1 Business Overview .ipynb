# %% [markdown]
# # Sentiment Analysis of Tweets on Apple and Google Products

# %% [markdown]
# ![](NLP_Image.jpg)

# %% [markdown]
# ##  1. BUSINESS OVERVIEW
#
# ###  1.1 **Business Understanding**
#
# #### 1.1.1 **What is  sentiment analysis?**
#
# **Sentiment Analysis** also known as **Sentiment Classification** in brief uses natural language processing to identify the emotional tone behind text, such as customer feedback, and categorize it as positive, negative, or neutral.
#
# The above can also be described as a text classification tasks, where we look at a phrase, or a list of phrases and use a classifier to tell if the sentiment behind that is:
# - positive
# - negative
# - neutral.
#
# In some cases, the third attribute is not taken to keep it a binary classification problem.
#
# In this project we will thus carry out a sentiment classification task where we will analyzes tweets, their emotions, and whether they are directed at a brand or product i.e Apple and Google products
#
# #### 1.1.2 **How is sentiment analysis important to an organization?**
#
# For your organization, sentiment analysis is crucial in the following ways:
#
# - Understanding customer opinions for improving experiences, and addressing concerns proactively.
# - It helps to predict customer behavior for a particular product
# - It can help to test the adaptability of a product
# - Automates the task of customer preference reports.
#
# The above are but a few benefits, but in general sentiment analysis assit business stake holders to also define various business problems regarding their products
# #### 1.1.3 **An Overview of Apple Products**
# Apple is one of the most recognized brands in the world valued at over $2 trillion in 2021. It is known for its innovative consumer electronics, including the iPhone, iPad, MacBook, and other devices. Apple’s next products, which may include a virtual reality headset and self-driving car. The past few product launches have been smaller in scope, like the HomePod and AirPod, and Apple fans are clamouring for the next iPhone.Given their wide range of products some mentioned above , below we have some statistics on their performance in 2023 as at September:
#
# - 231 million iPhones, 49 million iPads and 22 million Mac and MacBook units were sold in 2023
# - Apple’s home and wearables division declined by 6.5% in 2023
# - It sold 75 million AirPods and 38 million Apple Watches in 2023
# - Apple Music has 93 million subscribers, Apple TV+ has 47 million
#
# To be able to consistently get high revenues, Apple needs to continuously carry out sentiment analysis on the users' strong emotional reactions to the brand , which frequently result in a mix of positive and negative sentiments in their data.Tweets being a source of helpful data , looking at Tweets on Apple products could, among other things, cover customer service experiences, software upgrades, or the introduction of new items.
#
#
# #### 1.1.4 **An Overview of Google Products**
#
# Google offers diverse products designed to enhance productivity, connectivity, and innovation.Key offerings include:
# - Google Search
# - Gmail
# - Google Drive
# - Google Workspace for organizing and collaborating
# - YouTube
# - Google Photos
# - Google Play for entertainment
# - Google Maps, Waze, and Google Earth for navigation.
# - Businesses benefit from Google Ads, Google Analytics, and Google Cloud Platform, while developers use tools like Firebase and   BigQuery.
#
# Additionally, smart devices like Pixel phones, Nest home products, and Chromecast provide cutting-edge hardware solutions. Overall, Google's products aim to simplify daily life, empower businesses, and connect the world. In 2021 Statistics Highlighting Google's performance showed a revenue of $278.1 billion. Similar to Apple, for Google to continue to thrive, sentiment analysis is thus crucial to check on matters such as customer satisfaction.
#
# #### 1.1.5 **Why Analyze Tweets?**
# - **Social Media Influence**: Platforms like Twitter have become primary channels where customers share their feedback, both positive and negative, about brands and products.
# - **Volume of Data**: The massive and real-time nature of tweets makes manual analysis impractical, necessitating automated solutions.
# - **Business Impact**: Sentiment analysis of tweets can provide actionable insights to enhance customer experience, refine marketing strategies, and maintain a competitive edge.
#
#
# #### 1.1.6   Stakeholders
#
# Sentiment analysis is important for various participants such as:
#
# - **Business Managers**: Understand customer satisfaction and drive decision-making.
# - **Marketing Teams**: Create sentiment-driven marketing campaigns.
# - **Customer Service Teams**: Prioritize resolving issues flagged in negative reviews.
#
# #### 1.1.7 **Challenges in Sentiment Analysis**
# - **Unstructured Data**: Tweets are often informal, with abbreviations, slang, and emojis, making preprocessing essential.
# - **Ambiguity**: Some texts may have mixed sentiments or implicit emotions that are challenging to classify.
# - **Scalability**: Handling and processing large datasets efficiently is a significant challenge.
#
# #### 1.1.8 **Proposed Solutions**
# ##### 1.1.8 Approach Methodology:
#
# ##### 1.To execute the sentiment analysis . The following is the execution plan:
# - Begin with simple approaches like bag-of-words or TF-IDF vectorization
# - Proceed to commplex methods (e.g., word embeddings or transformers)
#
# ##### 2. Pre-trained Tools:
# * NLP has many pre-trained models (e.g., spaCy, NLTK, Hugging Face Transformers) and libraries for quick text processing.
#
# For example, use:
# - TF-IDF + Logistic Regression for a baseline.
# - Pre-trained embeddings (e.g., Word2Vec, GloVe) for better results.
# - Fine-tuned BERT if there is access to good hardware.
#
# #### 1.1.9 Projected Conclusion

# %% [markdown]
# ###  1.2 **Problem statement**
#
# #### 1.2.1  Business Problem:
# - In today’s digital world, customer feedback plays a critical role in shaping business decisions. Companies receive large volumes of unstructured textual data in the form of reviews, surveys, and social media posts. Analyzing this data manually is time-consuming and error-prone.
#
# The goal of this project is to build a sentiment analysis model that classifies customer feedback as positive, negative, or neutral.
#
# This will enable businesses to:
# - Identify key areas for improvement.
# - Tailor marketing strategies based on customer sentiment.
# - Monitor brand reputation over time.

# %% [markdown]
# ###  1.3 **Objectives**
#
# #### 1. **Primary Objective**:
#    - Build an unsupervised machine learning-based sentiment classification model that categorizes tweets as **positive**, **negative** towards a brand or product.
#
# #### 2. **Secondary Objectives**:
#
#    - Identify whether a tweet contains an emotion directed at a specific brand or product.
#    - Preprocess and clean the tweet text to remove noise (e.g., hashtags, mentions, and URLs).
#    - Identify the most positive words directed at apple and google company's products/services
#    - identify the most negative words directed at apple and google company's products/ services
#    - Provide actionable insights to help businesses improve customer satisfaction and marketing strategies.
#
#
# ###  1.3.1 **Key Questions to Address**
# 1. How can we preprocess and clean textual data effectively to extract meaningful insights?
# 2. What are the best features to use (e.g., word embeddings, TF-IDF, or sentiment lexicons) for classifying tweet sentiment?
# 3. Which supervised learning models (e.g., Logistic Regression, Random Forest, or BERT) perform best for this task?
# 4. What level of accuracy, precision, and recall can we achieve for sentiment classification?

# %% [markdown]
# ###  1.4 **Metrics of Success**
#
# To evaluate the success of our sentiment analysis model, we will use metrics such as; accuracy, precision, recall or sensitivity, f1 score and the confusion matrix. To evaluate the performance of the sentiment classification model, we will use the following metrics:
# #### 1. **Accuracy**:
#    - Accuracy will check at the percentage of the correctly classified instances of sentiments out of the total sentmental            instances.
#    - Target: **85% or higher**.
#
# #### 2. **Precision**:
#    - Precision will tell the percentage of actually correct positive sentiment predictions, thus telling us how often the model      is correct when it predicts a positive sentiment. The percentage of actual positive sentiments, that are correctly              identified by the model will be shown by recall. This metrics is important to strike a tradeoff between true positives and      false negatives
#    - Target: **80% or higher** for each class (positive, negative, neutral).
#
# #### 3. **Recall**:
#    - Measure the model’s ability to correctly identify all relevant examples of a specific sentiment.
#    - Target: **75% or higher** for each class.
#
# #### 4. **F1-Score**:
#    - Provide a balanced metric that considers both precision and recall.
#    - Target: **80% or higher** overall.
#
# #### 5. **Business Impact**:
#    - Improved customer satisfaction through the identification of key negative sentiments.
#    - Better marketing strategies based on trends in positive feedback.

# %% [markdown]
# ### 2. DATA UNDERSTANDING
# * Now we load the data, and proceed with understanding the shape, the basic statistics and the types of variable.
# * We write function that we can load the data and get back the shape, info and description with df.shape, df.describe(), df.info() and df.isnull().sum()

# %% [markdown]
# #### 2.1 Import Necessary Libraries

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import re
import Project_Functions as Pf
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import words



from nltk.tokenize import word_tokenize

# Download NLTK resources
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('words')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %% [markdown]
# #### 2.2 General  Dataset Exploration

# %%
# Load and Display the first few rows of the dataset
df = Pf.Load_dataset('judge-1377884607_tweet_product_company.csv')
df
# Out:
#                                                                                                                                              tweet_text  \
# 0                       .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1           @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2                                                                       @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3                                                                    @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4                   @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
# ...                                                                                                                                                 ...
# 9088                                                                                                                      Ipad everywhere. #SXSW {link}
# 9089                      Wave, buzz... RT @mention We interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 9090  Google's Zeiger, a physician never reported potential AE. Yet FDA relies on physicians. &quot;We're operating w/out data.&quot; #sxsw #health2dev
# 9091       Some Verizon iPhone customers complained their time fell back an hour this weekend.  Of course they were the New Yorkers who attended #SXSW.
# 9092                                           Ï¡Ïàü_ÊÎÒ£Áââ_£â_ÛâRT @mention Google Tests ÛÏCheck-in OffersÛ At #SXSW {link}
#
#      emotion_in_tweet_is_directed_at  \
# 0                             iPhone
# 1                 iPad or iPhone App
# 2                               iPad
# 3                 iPad or iPhone App
# 4                             Google
# ...                              ...
# 9088                            iPad
# 9089                             NaN
# 9090                             NaN
# 9091                             NaN
# 9092                             NaN
#
#      is_there_an_emotion_directed_at_a_brand_or_product
# 0                                      Negative emotion
# 1                                      Positive emotion
# 2                                      Positive emotion
# 3                                      Negative emotion
# 4                                      Positive emotion
# ...                                                 ...
# 9088                                   Positive emotion
# 9089                 No emotion toward brand or product
# 9090                 No emotion toward brand or product
# 9091                 No emotion toward brand or product
# 9092                 No emotion toward brand or product
#
# [9093 rows x 3 columns]

# %%
# Show the data information
Pf.check_Info(df)
# Out:
# ===============The dataset Shape=================
# (9093, 3)
# ===============The dataset columns=================
# Index(['tweet_text', 'emotion_in_tweet_is_directed_at',
#        'is_there_an_emotion_directed_at_a_brand_or_product'],
#       dtype='object')
# ===============The data_types=================
# tweet_text                                            object
# emotion_in_tweet_is_directed_at                       object
# is_there_an_emotion_directed_at_a_brand_or_product    object
# dtype: object
# ===============The dataset information=================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9093 entries, 0 to 9092
# Data columns (total 3 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   tweet_text                                          9092 non-null   object
#  1   emotion_in_tweet_is_directed_at                     3291 non-null   object
#  2   is_there_an_emotion_directed_at_a_brand_or_product  9093 non-null   object
# dtypes: object(3)
# memory usage: 213.2+ KB
# None
# ===============Check for Missing values=================
# tweet_text                                               1
# emotion_in_tweet_is_directed_at                       5802
# is_there_an_emotion_directed_at_a_brand_or_product       0
# dtype: int64
# ===============Check for Duplicated Rows=================
# 22
# ===============The dataset Description=================
#                                                                                                             tweet_text  \
# count                                                                                                             9092
# unique                                                                                                            9065
# top     RT @mention Marissa Mayer: Google Will Connect the Digital &amp; Physical Worlds Through Mobile - {link} #sxsw
# freq                                                                                                                 5
#
#        emotion_in_tweet_is_directed_at  \
# count                             3291
# unique                               9
# top                               iPad
# freq                               946
#
#        is_there_an_emotion_directed_at_a_brand_or_product
# count                                                9093
# unique                                                  4
# top                    No emotion toward brand or product
# freq                                                 5389

# %%
# Check for unique categories in emotion_in_tweet_is_directed_at column
df['emotion_in_tweet_is_directed_at'].unique()
# Out:
# array(['iPhone', 'iPad or iPhone App', 'iPad', 'Google', nan, 'Android',
#        'Apple', 'Android App', 'Other Google product or service',
#        'Other Apple product or service'], dtype=object)

# %%
# Check for unique categories in Emotion-directed column
df['is_there_an_emotion_directed_at_a_brand_or_product'].unique()
# Out:
# array(['Negative emotion', 'Positive emotion',
#        'No emotion toward brand or product', "I can't tell"], dtype=object)

# %% [markdown]
# * The dataset comprise of 9093 rows and 3 columns; the **tweet_text**,**emotion_in_tweet_is_directed_at** and **is_there_an_emotion_directed_at_a_brand_or_product**.
# * The tweet_text column contain the tweet or the text written on the twitter platform. The emotiom_in_tweet_is_directed_at column shows items produced as products or evene services by Apple and Google, that the tweets were directed at. The last column shows whether the tweet written had a positive, negative or neutral impact.
# * All the columns are of the object data type.
# * There are 5802 missing entries in the 'emotion_in_tweet_is_directed_at' column and one missing entry in the tweet_text column.
# * There are 22 duplicated entries.
# * Additionally unique categories were identified in the emotion_in_tweet_is_directed_at column and is_there_an_emotion_directed_at_a_brand_or_product column

# %% [markdown]
# ### 3. DATA PREPARATION
# The data understanding section above checked for non null values, duplicates to gain surface level insights. This section delves into data preparation by performing various transformations suitable format for modelling.
# But first we need to do a bit of data cleaning.
# ####  3.1  Data Cleaning
# 1. Deal with the missing values in the tweet_text and emotion_in_tweet_is_directed_at columns
# 2. Deal with Duplicates
# 3. Dealing with the text case
# 4. Further cleaning and transformation; Removing specific words and numbers in the text.

# %% [markdown]
# #####  3.1.1  Duplicates
# * Drop the duplicated rows.
# Rationale; The total number of duplictes, i.e 22. we remove them to maintain the integrity of our data set and only ensure only unique observations are considered.

# %%
df = df.drop_duplicates(keep='first')

# %% [markdown]
# #####  3.1.2  Missing Values
# * Drop the row with missing values in the tweet_text column. Implement the use of the dropna() pandas method.
# * The 'emotion_in_tweet_is_directed_at' column, require strict check in regard to its contribution to the final model. Check for the percentage of the missing values; above 50%. With the trade off between droping this column and retaining it, try a method to get an absolute and rational values for the missing entries.
# * Loop through the tweet_text column texts and check for a probable entry. Fill in this entries to a new column. To do this, first, clean the tweet_text column and create a column for the cleaned text, then extract the possible entries.

# %%
# check the missing values in the tweet_text column
df[df['tweet_text'].isna()]
# Out:
#   tweet_text emotion_in_tweet_is_directed_at  \
# 6        NaN                             NaN
#
#   is_there_an_emotion_directed_at_a_brand_or_product
# 6                 No emotion toward brand or product

# %%
# Drop the missing value in tweet_text column. Only one was identified above
df = df.dropna(subset = ['tweet_text'])

# %%
# Check if missing value is removed in tweet , also check remaining missing values in other columns
Pf.check_for_missing_values(df)
# Out:
# tweet_text                                               0
# emotion_in_tweet_is_directed_at                       5788
# is_there_an_emotion_directed_at_a_brand_or_product       0
# dtype: int64

# %%
# check for the percentage distribution of missing values
missing_percentage = df['emotion_in_tweet_is_directed_at'].isna().value_counts(normalize = True)* 100
# Format the percentages to include the '%' symbol
missing_percentage = missing_percentage.apply(lambda x: f"{x:.2f}%")
missing_percentage
# Out:
# True     63.81%
# False    36.19%
# Name: emotion_in_tweet_is_directed_at, dtype: object

# %% [markdown]
# #####  3.1.2.1  Dealing with the text column
# 1. Basic cleaning: removing capitalization, special characters such as ?,;., converting to lower case
# 2. Tokenizing our texts column
# 3. create a new column with joined words
# 4. removing the stopwords
#
# * First extract the words in the tweet_text column that starts with '@' and those starting with '#'. words starting with @ refers to the person who tweeted while those those starting with # refers to those who were tagged. worth notting that these words in our texts will be adding noise to our data_set.
# * Extract the users and the tagged into separate columns.

# %%
import re
# Regular expression to extract Twitter usernames
pattern = r"@\w+"
pattern_2 = r'#\w+'

# Extract usernames from the 'Tweets' column
df['Usernames'] = df['tweet_text'].apply(lambda x: re.findall(pattern, x))
df['Tagged_Names'] = df['tweet_text'].apply(lambda x: re.findall(pattern_2, x))

df.head()
# Out:
#                                                                                                                                     tweet_text  \
# 0              .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2                                                              @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3                                                           @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4          @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#   emotion_in_tweet_is_directed_at  \
# 0                          iPhone
# 1              iPad or iPhone App
# 2                            iPad
# 3              iPad or iPhone App
# 4                          Google
#
#   is_there_an_emotion_directed_at_a_brand_or_product              Usernames  \
# 0                                   Negative emotion            [@wesley83]
# 1                                   Positive emotion  [@jessedee, @fludapp]
# 2                                   Positive emotion          [@swonderlin]
# 3                                   Negative emotion                [@sxsw]
# 4                                   Positive emotion           [@sxtxstate]
#
#             Tagged_Names
# 0  [#RISE_Austin, #SXSW]
# 1                [#SXSW]
# 2         [#iPad, #SXSW]
# 3                [#sxsw]
# 4                [#SXSW]

# %% [markdown]
# #####  3.1.2.2  Converting the tweet_text to lower case
# * Write a function to access the tweets in the column, tweet_text, and lower case.
# * Remove the usernames and tagged names in the texts and create the column 'clean_tweet_text' for the cleaned text

# %%
# Transform the whole dataset (df[tweet_text]) to lowercase
df["tweet_text"] = df["tweet_text"].str.lower()
# Display full text: uncomment the code below to display the whole texts
#df.style.set_properties(**{'text-align': 'left'})

# %%
import re
def remove_urls(text, replacement_text= ' url'):
    url_pattern = re.compile(r'https?:\/\/\S+|www\.\S+')
    urls = url_pattern.findall(text)
    
    for url in urls:
        text = text.replace(url, replacement_text)
    return text
# Create new column with tokenized data
df["clean_tweet_text"] = df["tweet_text"].apply(remove_urls)

# %%
df['clean_tweet_text'][678]
# Out:
# '#thekills interview now on @mention at #sxsw may be one of the most painfully vacuous interviews in history. {link}'

# %%
df.columns
df = df[['tweet_text','clean_tweet_text', 'emotion_in_tweet_is_directed_at',
       'is_there_an_emotion_directed_at_a_brand_or_product', 'Usernames',
       'Tagged_Names']]
df.head(4)
# Out:
#                                                                                                                                     tweet_text  \
# 0              .@wesley83 i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 1  @jessedee know about @fludapp ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at #sxsw
# 2                                                              @swonderlin can not wait for #ipad 2 also. they should sale them down at #sxsw.
# 3                                                           @sxsw i hope this year's festival isn't as crashy as this year's iphone app. #sxsw
#
#                                                                                                                               clean_tweet_text  \
# 0              .@wesley83 i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 1  @jessedee know about @fludapp ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at #sxsw
# 2                                                              @swonderlin can not wait for #ipad 2 also. they should sale them down at #sxsw.
# 3                                                           @sxsw i hope this year's festival isn't as crashy as this year's iphone app. #sxsw
#
#   emotion_in_tweet_is_directed_at  \
# 0                          iPhone
# 1              iPad or iPhone App
# 2                            iPad
# 3              iPad or iPhone App
#
#   is_there_an_emotion_directed_at_a_brand_or_product              Usernames  \
# 0                                   Negative emotion            [@wesley83]
# 1                                   Positive emotion  [@jessedee, @fludapp]
# 2                                   Positive emotion          [@swonderlin]
# 3                                   Negative emotion                [@sxsw]
#
#             Tagged_Names
# 0  [#RISE_Austin, #SXSW]
# 1                [#SXSW]
# 2         [#iPad, #SXSW]
# 3                [#sxsw]

# %%
# Create a function that removes words starting with @ and #
def remove_words_with_at_and_hash(text):
    # Use a regular expression to remove words containing "@" and words starting with "#"
    cleaned_text = re.sub(r'\S*@\S*|#\w+','', text)
  
    return cleaned_text
# Create new column with tokenized data
df["clean_tweet_text"] = df["clean_tweet_text"].apply(remove_words_with_at_and_hash)
# Display full text: uncomment the code below to display the whole texts
#df.style.set_properties(**{'text-align': 'left'})
df.head()
# Out:
#                                                                                                                                     tweet_text  \
# 0              .@wesley83 i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 1  @jessedee know about @fludapp ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at #sxsw
# 2                                                              @swonderlin can not wait for #ipad 2 also. they should sale them down at #sxsw.
# 3                                                           @sxsw i hope this year's festival isn't as crashy as this year's iphone app. #sxsw
# 4          @sxtxstate great stuff on fri #sxsw: marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
#
#                                                                                                         clean_tweet_text  \
# 0                    i have a 3g iphone. after 3 hrs tweeting at , it was dead!  i need to upgrade. plugin stations at .
# 1   know about  ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at
# 2                                                              can not wait for  2 also. they should sale them down at .
# 3                                                i hope this year's festival isn't as crashy as this year's iphone app.
# 4    great stuff on fri : marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
#
#   emotion_in_tweet_is_directed_at  \
# 0                          iPhone
# 1              iPad or iPhone App
# 2                            iPad
# 3              iPad or iPhone App
# 4                          Google
#
#   is_there_an_emotion_directed_at_a_brand_or_product              Usernames  \
# 0                                   Negative emotion            [@wesley83]
# 1                                   Positive emotion  [@jessedee, @fludapp]
# 2                                   Positive emotion          [@swonderlin]
# 3                                   Negative emotion                [@sxsw]
# 4                                   Positive emotion           [@sxtxstate]
#
#             Tagged_Names
# 0  [#RISE_Austin, #SXSW]
# 1                [#SXSW]
# 2         [#iPad, #SXSW]
# 3                [#sxsw]
# 4                [#SXSW]

# %% [markdown]
# * Now loop through the tweet_text column and check for a probable entry. Fill in this entries to a new column, category_words.

# %%
categories = ['iPhone', 'iPad or iPhone App', 'iPad', 'Google','Android',
       'Apple', 'Android App', 'Other Google product or service',
       'Other Apple product or service']
len(categories)
# Out:
# 9

# %%
def extract_category_words(tweet, categories):
    # Tokenize and check for category words
    extracted_words = []
    for category in categories:
        if category.lower() in tweet.lower():
            extracted_words.append(category)
    return " ".join(extracted_words)
df['Tweet_Directed_at'] = df['clean_tweet_text'].apply(lambda x: extract_category_words(x, categories))
# Check for the value counts in the new category column
df['Tweet_Directed_at'].value_counts()
# Out:
# Google                        2153
#                               1784
# iPad                          1714
# Apple                         1191
# iPhone                        1040
# iPad Apple                     567
# Android                        240
# iPhone Android                 118
# iPhone iPad                    103
# Android Android App             30
# iPad Android                    23
# Google Apple                    23
# iPhone Apple                    23
# Google Android                  15
# iPhone Android Android App      10
# iPad Google                     10
# iPhone iPad Android              8
# Android Apple                    7
# iPhone iPad Apple                4
# iPhone Google                    3
# iPhone iPad Google               2
# iPhone Google Android            2
# Name: Tweet_Directed_at, dtype: int64

# %%
pd.set_option('display.max_colwidth', None)
df['clean_tweet_text'][0:20]
# Out:
# 0                       i have a 3g iphone. after 3 hrs tweeting at , it was dead!  i need to upgrade. plugin stations at .
# 1      know about  ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at
# 2                                                                 can not wait for  2 also. they should sale them down at .
# 3                                                   i hope this year's festival isn't as crashy as this year's iphone app.
# 4       great stuff on fri : marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
# 5                                             new ipad apps for  and communication are showcased at the  conference  url
# 7            is just starting,  is around the corner and  is only a hop skip and a jump from there, good time to be an  fan
# 8                                               beautifully smart and simple idea rt   wrote about our  ipad app for !  url
# 9                                       counting down the days to  plus strong canadian dollar means stock up on apple gear
# 10                             excited to meet the  at  so i can show them my sprint galaxy s still running android 2.1.
# 11                            find &amp; start impromptu parties at  with   url i can't wait til the android app comes out.
# 12                foursquare ups the game, just in time for   url - still prefer  by far, best looking android app to date.
# 13                     gotta love this  google calendar featuring top parties/ show cases to check out.  rt  via  =&gt; url
# 14                                                                                               great  ipad app from   url
# 15                                                                                  haha, awesomely rad ipad app by   url
# 16                                                              holler gram for ipad on the itunes app store -   url (via
# 17     i just noticed dst is coming this weekend. how many iphone users will be an hour late at sxsw come sunday morning?
# 18             just added my  flights to  matching people on planes/airports. also downloaded the  iphone app, nicely done.
# 19                                   must have  app! rt  lovely review from forbes for our sxsw ipad app holler gram -  url
# 20                    need to buy an ipad2 while i'm in austin at . not sure if i'll need to q up at an austin apple store?
# Name: clean_tweet_text, dtype: object

# %%
# Rearranging the dataframe.
df= df[['tweet_text', 'clean_tweet_text','emotion_in_tweet_is_directed_at','Tweet_Directed_at',
       'is_there_an_emotion_directed_at_a_brand_or_product']]
df.head()
# Out:
#                                                                                                                                     tweet_text  \
# 0              .@wesley83 i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 1  @jessedee know about @fludapp ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at #sxsw
# 2                                                              @swonderlin can not wait for #ipad 2 also. they should sale them down at #sxsw.
# 3                                                           @sxsw i hope this year's festival isn't as crashy as this year's iphone app. #sxsw
# 4          @sxtxstate great stuff on fri #sxsw: marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
#
#                                                                                                         clean_tweet_text  \
# 0                    i have a 3g iphone. after 3 hrs tweeting at , it was dead!  i need to upgrade. plugin stations at .
# 1   know about  ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at
# 2                                                              can not wait for  2 also. they should sale them down at .
# 3                                                i hope this year's festival isn't as crashy as this year's iphone app.
# 4    great stuff on fri : marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
#
#   emotion_in_tweet_is_directed_at Tweet_Directed_at  \
# 0                          iPhone            iPhone
# 1              iPad or iPhone App       iPhone iPad
# 2                            iPad
# 3              iPad or iPhone App            iPhone
# 4                          Google            Google
#
#   is_there_an_emotion_directed_at_a_brand_or_product
# 0                                   Negative emotion
# 1                                   Positive emotion
# 2                                   Positive emotion
# 3                                   Negative emotion
# 4                                   Positive emotion

# %% [markdown]
# * From above display of the value counts, the category_words columns have 1781 null entries.
# * Loop through the 'category_words' to determine which entries were null. For the indices of the null entries, check if they are present in the 'emotion_in_tweet_is_directed_at' column. If present, fill in the null entries in the category_words.
# * Access the value counts of the category_words column to verify the decrease in the null entries. Notice a decrease in the number of null entries.
# * Proceed to drop the rows with null entries.

# %%
import pandas as pd

def update_tweet_directed_at(df):
    # Condition where 'emotion_in_tweet_is_directed_at' has data, 
    # but 'Tweet_Directed_at' is blank or NaN
    condition_a_data_b_blank = (df['emotion_in_tweet_is_directed_at'].notna() & 
                                (df['emotion_in_tweet_is_directed_at'] != "") & 
                                (df['Tweet_Directed_at'].isna() | (df['Tweet_Directed_at'] == "")))
    
#     # Show the value counts of the condition (optional step)
#     print("Condition A: Emotion In Data, Tweet Directed At is Blank - Value Counts")
#     print(condition_a_data_b_blank.value_counts())
    
    # Update 'Tweet_Directed_at' with 'emotion_in_tweet_is_directed_at' where the condition is true
    df.loc[condition_a_data_b_blank, 'Tweet_Directed_at'] = df.loc[condition_a_data_b_blank, 'emotion_in_tweet_is_directed_at']
    
#     # Show the value counts of the updated 'Tweet_Directed_at' column (optional step)
#     print("Updated Tweet_Directed_at - Value Counts")
#     print(df['Tweet_Directed_at'].value_counts())
    
    # Return the modified DataFrame
    return df

# %%
update_tweet_directed_at(df)
# Out:
#                                                                                                                                              tweet_text  \
# 0                       .@wesley83 i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 1           @jessedee know about @fludapp ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at #sxsw
# 2                                                                       @swonderlin can not wait for #ipad 2 also. they should sale them down at #sxsw.
# 3                                                                    @sxsw i hope this year's festival isn't as crashy as this year's iphone app. #sxsw
# 4                   @sxtxstate great stuff on fri #sxsw: marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
# ...                                                                                                                                                 ...
# 9088                                                                                                                      ipad everywhere. #sxsw {link}
# 9089                      wave, buzz... rt @mention we interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 9090  google's zeiger, a physician never reported potential ae. yet fda relies on physicians. &quot;we're operating w/out data.&quot; #sxsw #health2dev
# 9091       some verizon iphone customers complained their time fell back an hour this weekend.  of course they were the new yorkers who attended #sxsw.
# 9092                                           ï¡ïàü_êîò£áââ_£â_ûârt @mention google tests ûïcheck-in offersû at #sxsw {link}
#
#                                                                                                                              clean_tweet_text  \
# 0                                         i have a 3g iphone. after 3 hrs tweeting at , it was dead!  i need to upgrade. plugin stations at .
# 1                        know about  ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at
# 2                                                                                   can not wait for  2 also. they should sale them down at .
# 3                                                                     i hope this year's festival isn't as crashy as this year's iphone app.
# 4                         great stuff on fri : marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
# ...                                                                                                                                       ...
# 9088                                                                                                                 ipad everywhere.  {link}
# 9089                                        wave, buzz... rt  we interrupt your regularly scheduled  geek programming with big news {link}
# 9090        google's zeiger, a physician never reported potential ae. yet fda relies on physicians. &quot;we're operating w/out data.&quot;
# 9091  some verizon iphone customers complained their time fell back an hour this weekend.  of course they were the new yorkers who attended .
# 9092                                              ï¡ïàü_êîò£áââ_£â_ûârt  google tests ûïcheck-in offersû at  {link}
#
#      emotion_in_tweet_is_directed_at Tweet_Directed_at  \
# 0                             iPhone            iPhone
# 1                 iPad or iPhone App       iPhone iPad
# 2                               iPad              iPad
# 3                 iPad or iPhone App            iPhone
# 4                             Google            Google
# ...                              ...               ...
# 9088                            iPad              iPad
# 9089                             NaN
# 9090                             NaN            Google
# 9091                             NaN            iPhone
# 9092                             NaN            Google
#
#      is_there_an_emotion_directed_at_a_brand_or_product
# 0                                      Negative emotion
# 1                                      Positive emotion
# 2                                      Positive emotion
# 3                                      Negative emotion
# 4                                      Positive emotion
# ...                                                 ...
# 9088                                   Positive emotion
# 9089                 No emotion toward brand or product
# 9090                 No emotion toward brand or product
# 9091                 No emotion toward brand or product
# 9092                 No emotion toward brand or product
#
# [9070 rows x 5 columns]

# %% [markdown]
# * Create a mapping for the either google products, apple products, unknown and IRR. Map this dictionary to create a column to show which company the tweet was directed at.

# %%
# Define mapping for fewer categories
category_mapping = {
    'Google': 'Google Products',
    'iPad': 'Apple Products',
    '': 'Unknown',
    'Apple': 'Apple Products',
    'iPhone': 'Apple Products',
    'iPad Apple': 'Apple Products',
    'Android': 'Google Products',
    'iPhone Android': 'IRR',
    'iPhone iPad': 'Apple Products',
    'iPad or iPhone App': 'Apple Products',
    'Android Android App': 'Google Products',
    'iPad Android': 'IRR',
    'iPhone Apple': 'Apple Products',
    'Google Apple': 'IRR',
    'Android App': 'Google Products',
    'Google Android': 'Google Products',
    'Other Google product or service': 'Google Products',
    'Other Apple product or service': 'Apple Products',
    'iPad Google': 'IRR',
    'iPhone Android Android App': 'IRR',
    'iPhone iPad Android': 'IRR',
    'Android Apple': 'IRR',
    'iPhone iPad Apple': 'Apple Products',
    'iPhone Google': 'IRR',
    'iPhone iPad Google': 'IRR',
    'iPhone Google Android': 'IRR'
}


# Apply mapping to the dataframe
df['Company_Product'] = df['Tweet_Directed_at'].map(category_mapping)
df.head()
# Display the result
df['Company_Product'].value_counts(normalize= True)
# Out:
# Apple Products     0.541014
# Google Products    0.278501
# Unknown            0.157773
# IRR                0.022712
# Name: Company_Product, dtype: float64

# %%
# checking for any null values in the Company_product column
df['Company_Product'].isna().sum()
# Out:
# 0

# %% [markdown]
# * We have now created a column where we have been able to map the various products. The missing values/ null values are now denoted with the word "Unknown".
# * Proceed to drop the "Unknown" and "IRR" which represents irrelevant categories in the column.
# * Then proceed to drop the 'emotion_in_tweet_is_directed_at' column, because the 'Company_product' is a better representative of this column. Now we have successfully dealt with the missing values. Proceed to dealing with the clean_tweet_text column semantic analysis.

# %%
# Droping rows with null entries
df = df[(df['Company_Product'] != 'Unknown') & (df['Company_Product'] != 'IRR')]
df = df.reset_index(drop=True)
# Confirm the null entries
Pf.check_for_missing_values(df)
# Out:
# tweet_text                                               0
# clean_tweet_text                                         0
# emotion_in_tweet_is_directed_at                       4213
# Tweet_Directed_at                                        0
# is_there_an_emotion_directed_at_a_brand_or_product       0
# Company_Product                                          0
# dtype: int64

# %%
# drop the emotion_in_tweet_is_directed_at column 
df.drop('emotion_in_tweet_is_directed_at', axis=1, inplace=True)
df.head()
# Out:
#                                                                                                                                     tweet_text  \
# 0              .@wesley83 i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 1  @jessedee know about @fludapp ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at #sxsw
# 2                                                              @swonderlin can not wait for #ipad 2 also. they should sale them down at #sxsw.
# 3                                                           @sxsw i hope this year's festival isn't as crashy as this year's iphone app. #sxsw
# 4          @sxtxstate great stuff on fri #sxsw: marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
#
#                                                                                                         clean_tweet_text  \
# 0                    i have a 3g iphone. after 3 hrs tweeting at , it was dead!  i need to upgrade. plugin stations at .
# 1   know about  ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at
# 2                                                              can not wait for  2 also. they should sale them down at .
# 3                                                i hope this year's festival isn't as crashy as this year's iphone app.
# 4    great stuff on fri : marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
#
#   Tweet_Directed_at is_there_an_emotion_directed_at_a_brand_or_product  \
# 0            iPhone                                   Negative emotion
# 1       iPhone iPad                                   Positive emotion
# 2              iPad                                   Positive emotion
# 3            iPhone                                   Negative emotion
# 4            Google                                   Positive emotion
#
#    Company_Product
# 0   Apple Products
# 1   Apple Products
# 2   Apple Products
# 3   Apple Products
# 4  Google Products

# %%
# Checking the tweet_text "is_there_an_emotion_directed_at_a_brand_or_product" column
# Recall that this column also has unique values , we will look at them
df['is_there_an_emotion_directed_at_a_brand_or_product'].value_counts()
# Out:
# No emotion toward brand or product    3884
# Positive emotion                      2856
# Negative emotion                       555
# I can't tell                           138
# Name: is_there_an_emotion_directed_at_a_brand_or_product, dtype: int64

# %%
# Check for NaNs
df['is_there_an_emotion_directed_at_a_brand_or_product'].isna().sum()
# Out:
# 0

# %%
# We will now streamline the categories into shorter forms such as "positive","negative","Neutral" 
# and "Unknown" using mapping
Updated_emotion_categories = {'Negative emotion': 'Negative', 'Positive emotion': 'Positive', 
                'No emotion toward brand or product': 'Neutral', 
                "I can't tell": 'Unknown'}
df['is_there_an_emotion_directed_at_a_brand_or_product'] = df['is_there_an_emotion_directed_at_a_brand_or_product'].map(Updated_emotion_categories)
df.head(5)
# Out:
#                                                                                                                                     tweet_text  \
# 0              .@wesley83 i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 1  @jessedee know about @fludapp ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at #sxsw
# 2                                                              @swonderlin can not wait for #ipad 2 also. they should sale them down at #sxsw.
# 3                                                           @sxsw i hope this year's festival isn't as crashy as this year's iphone app. #sxsw
# 4          @sxtxstate great stuff on fri #sxsw: marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
#
#                                                                                                         clean_tweet_text  \
# 0                    i have a 3g iphone. after 3 hrs tweeting at , it was dead!  i need to upgrade. plugin stations at .
# 1   know about  ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at
# 2                                                              can not wait for  2 also. they should sale them down at .
# 3                                                i hope this year's festival isn't as crashy as this year's iphone app.
# 4    great stuff on fri : marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
#
#   Tweet_Directed_at is_there_an_emotion_directed_at_a_brand_or_product  \
# 0            iPhone                                           Negative
# 1       iPhone iPad                                           Positive
# 2              iPad                                           Positive
# 3            iPhone                                           Negative
# 4            Google                                           Positive
#
#    Company_Product
# 0   Apple Products
# 1   Apple Products
# 2   Apple Products
# 3   Apple Products
# 4  Google Products

# %%
df['is_there_an_emotion_directed_at_a_brand_or_product'].isnull().sum()
# Out:
# 0

# %%
df['clean_tweet_text'][0:20]
# Out:
# 0                       i have a 3g iphone. after 3 hrs tweeting at , it was dead!  i need to upgrade. plugin stations at .
# 1      know about  ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at
# 2                                                                 can not wait for  2 also. they should sale them down at .
# 3                                                   i hope this year's festival isn't as crashy as this year's iphone app.
# 4       great stuff on fri : marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
# 5                                             new ipad apps for  and communication are showcased at the  conference  url
# 6            is just starting,  is around the corner and  is only a hop skip and a jump from there, good time to be an  fan
# 7                                               beautifully smart and simple idea rt   wrote about our  ipad app for !  url
# 8                                       counting down the days to  plus strong canadian dollar means stock up on apple gear
# 9                              excited to meet the  at  so i can show them my sprint galaxy s still running android 2.1.
# 10                            find &amp; start impromptu parties at  with   url i can't wait til the android app comes out.
# 11                foursquare ups the game, just in time for   url - still prefer  by far, best looking android app to date.
# 12                     gotta love this  google calendar featuring top parties/ show cases to check out.  rt  via  =&gt; url
# 13                                                                                               great  ipad app from   url
# 14                                                                                  haha, awesomely rad ipad app by   url
# 15                                                              holler gram for ipad on the itunes app store -   url (via
# 16     i just noticed dst is coming this weekend. how many iphone users will be an hour late at sxsw come sunday morning?
# 17             just added my  flights to  matching people on planes/airports. also downloaded the  iphone app, nicely done.
# 18                                   must have  app! rt  lovely review from forbes for our sxsw ipad app holler gram -  url
# 19                    need to buy an ipad2 while i'm in austin at . not sure if i'll need to q up at an austin apple store?
# Name: clean_tweet_text, dtype: object

# %%
# Get the value counts for the emotion-directed column
Count_emotion = df['is_there_an_emotion_directed_at_a_brand_or_product'].value_counts()

# Calculate the percentage for each category
percentage_emotion = df['is_there_an_emotion_directed_at_a_brand_or_product'].value_counts(normalize=True) * 100

# Combine both count and percentage into a DataFrame
result_emotion = pd.DataFrame({
    'Count': Count_emotion,
    'Percentage': percentage_emotion.apply(lambda x: f"{x:.2f}%")  # Format percentage to 2 decimal places
})

result_emotion
# Out:
#           Count Percentage
# Neutral    3884     52.25%
# Positive   2856     38.42%
# Negative    555      7.47%
# Unknown     138      1.86%

# %%
# Checking sample data of the "Unknown" emotion category
pd.set_option("display.max_colwidth", 300)
Emotion_Unknown = df[df['is_there_an_emotion_directed_at_a_brand_or_product']=='Unknown']
Emotion_Unknown.head()
# Out:
#                                                                                                                           tweet_text  \
# 76   ûï@mention &quot;apple has opened a pop-up store in austin so the nerds in town for #sxsw can get their new ipads. {link} #wow
# 189       just what america needs. rt @mention google to launch major new social network called circles, possibly today {link} #sxsw
# 286                                                   the queue at the apple store in austin is four blocks long. crazy stuff! #sxsw
# 308                hope it's better than wave rt @mention buzz is: google's previewing a social networking platform at #sxsw: {link}
# 344                                                                  syd #sxsw crew your iphone extra juice pods have been procured.
#
#                                                                                                   clean_tweet_text  \
# 76      &quot;apple has opened a pop-up store in austin so the nerds in town for  can get their new ipads. {link}
# 189  just what america needs. rt  google to launch major new social network called circles, possibly today {link}
# 286                                      the queue at the apple store in austin is four blocks long. crazy stuff!
# 308           hope it's better than wave rt  buzz is: google's previewing a social networking platform at : {link}
# 344                                                     syd  crew your iphone extra juice pods have been procured.
#
#     Tweet_Directed_at is_there_an_emotion_directed_at_a_brand_or_product  \
# 76         iPad Apple                                            Unknown
# 189            Google                                            Unknown
# 286             Apple                                            Unknown
# 308            Google                                            Unknown
# 344            iPhone                                            Unknown
#
#      Company_Product
# 76    Apple Products
# 189  Google Products
# 286   Apple Products
# 308  Google Products
# 344   Apple Products

# %%
df.loc[8:15, 'clean_tweet_text']
# Out:
# 8                           counting down the days to  plus strong canadian dollar means stock up on apple gear
# 9                  excited to meet the  at  so i can show them my sprint galaxy s still running android 2.1.
# 10                find &amp; start impromptu parties at  with   url i can't wait til the android app comes out.
# 11    foursquare ups the game, just in time for   url - still prefer  by far, best looking android app to date.
# 12         gotta love this  google calendar featuring top parties/ show cases to check out.  rt  via  =&gt; url
# 13                                                                                   great  ipad app from   url
# 14                                                                      haha, awesomely rad ipad app by   url
# 15                                                  holler gram for ipad on the itunes app store -   url (via
# Name: clean_tweet_text, dtype: object

# %% [markdown]
# Given the first 5 rows, it is clear that, it is not clear what emotion is really being captured in the tweet, Some of the tweets might be sarcastic or actually genuine but we cannot tell. However from the value count seen above , the number of the "Unknown" emotion is not significant(1.8% of the total data in the "emotion" column). It is therefore more prudent to drop them.

# %%
df=df[df['is_there_an_emotion_directed_at_a_brand_or_product']!='Unknown']
df['is_there_an_emotion_directed_at_a_brand_or_product'].value_counts()
# Out:
# Neutral     3884
# Positive    2856
# Negative     555
# Name: is_there_an_emotion_directed_at_a_brand_or_product, dtype: int64

# %%
Pf.data_shape(df)
# Out:
# (7295, 5)

# %% [markdown]
# ####  3.2 Additional Data Cleaning & EDA with NLTK
#
# For this section we will start by focusing on Positive and the Negative emotions captured in the "is_there_an_emotion_directed_at_a_brand-or_product column as it is our objective to analyze those two categories.
#
# We will use first start by removing the following from the clean_tweet_text column :
#
# 1. Remove URLs
# 2. remove non-alphanumeric characters
# 3. Remove numbers/ digits
#
# #####  3.2.1
# * In this section we access the clean_tweet_text column check for the appropriate checks in the text. For instance, removal of special characters, Urls and numbers/digits.
# * Create a function that removes all the instances above.
# * Access specific text, perform the transformations and apply to the whole dataframe.

# %%
df.head()
# Out:
#                                                                                                                                     tweet_text  \
# 0              .@wesley83 i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 1  @jessedee know about @fludapp ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at #sxsw
# 2                                                              @swonderlin can not wait for #ipad 2 also. they should sale them down at #sxsw.
# 3                                                           @sxsw i hope this year's festival isn't as crashy as this year's iphone app. #sxsw
# 4          @sxtxstate great stuff on fri #sxsw: marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
#
#                                                                                                         clean_tweet_text  \
# 0                    i have a 3g iphone. after 3 hrs tweeting at , it was dead!  i need to upgrade. plugin stations at .
# 1   know about  ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at
# 2                                                              can not wait for  2 also. they should sale them down at .
# 3                                                i hope this year's festival isn't as crashy as this year's iphone app.
# 4    great stuff on fri : marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
#
#   Tweet_Directed_at is_there_an_emotion_directed_at_a_brand_or_product  \
# 0            iPhone                                           Negative
# 1       iPhone iPad                                           Positive
# 2              iPad                                           Positive
# 3            iPhone                                           Negative
# 4            Google                                           Positive
#
#    Company_Product
# 0   Apple Products
# 1   Apple Products
# 2   Apple Products
# 3   Apple Products
# 4  Google Products

# %%
pd.set_option('display.max_colwidth', None)
df['clean_tweet_text'][60:70]
# Out:
# 60                                                    i love my  iphone case from  but i can't get my phone out of it
# 61               ipad2? rt  droid &amp; mac here :) rt  my  confession, using laptop, ipad &amp; blackberry to follow
# 62                 new post:  iphone app makes it easy to connect on all social networks with people you meet  {link}
# 63                                        nice that  iphone app is behaving today. crashes yesterday were ridiculous.
# 64                         nice!  rt  apple opening popup store for ipad launch in downtown austin during  {link} via
# 65      nice!! rt  hey, apple fans! get a peek at the space that's slated to be a pop-up  apple store tomorrow: {link}
# 66    one thing  is doing so great is get a great, down to earth face to google as a company - you can only love her
# 67                             thanks to  for her mention of our new  ipad apps being showcased at the  conf. {link}
# 68                       what !?!?    does not provide iphone chargers?!?  i've changed my mind about going next year!
# 69                                                   wonder if  &amp;  will be in the apple flashmob: tcrn.ch/fcs45j
# Name: clean_tweet_text, dtype: object

# %%
sentence = df["clean_tweet_text"][36]
sentence
# Out:
# '  - false alarm: google circles not coming now\x89ûòand probably not ever? - {link}    '

# %%
# Import the regexptokenizer
# Check how it works on the example sentence above
from nltk.tokenize import RegexpTokenizer

basic_token_pattern = r"(?u)\b\w\w+\b"

tokenizer = RegexpTokenizer(basic_token_pattern)
tokenizer.tokenize(sentence)
# Out:
# ['false',
#  'alarm',
#  'google',
#  'circles',
#  'not',
#  'coming',
#  'now',
#  'ûòand',
#  'probably',
#  'not',
#  'ever',
#  'link']

# %% [markdown]
# * Notice that the regexpTokenizer removes some special characters, including urls. It splits the specific words and puts them into a list. However the it does not remove the stopwords/ filler words and numbers.

# %%
# Create new column with tokenized data
df["text_tokenized"] = df["clean_tweet_text"].apply(tokenizer.tokenize)
# Display full text
#df.style.set_properties(**{'text-align': 'left'})
df.head()
# Out:
#                                                                                                                                     tweet_text  \
# 0              .@wesley83 i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 1  @jessedee know about @fludapp ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at #sxsw
# 2                                                              @swonderlin can not wait for #ipad 2 also. they should sale them down at #sxsw.
# 3                                                           @sxsw i hope this year's festival isn't as crashy as this year's iphone app. #sxsw
# 4          @sxtxstate great stuff on fri #sxsw: marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
#
#                                                                                                         clean_tweet_text  \
# 0                    i have a 3g iphone. after 3 hrs tweeting at , it was dead!  i need to upgrade. plugin stations at .
# 1   know about  ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at
# 2                                                              can not wait for  2 also. they should sale them down at .
# 3                                                i hope this year's festival isn't as crashy as this year's iphone app.
# 4    great stuff on fri : marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
#
#   Tweet_Directed_at is_there_an_emotion_directed_at_a_brand_or_product  \
# 0            iPhone                                           Negative
# 1       iPhone iPad                                           Positive
# 2              iPad                                           Positive
# 3            iPhone                                           Negative
# 4            Google                                           Positive
#
#    Company_Product  \
# 0   Apple Products
# 1   Apple Products
# 2   Apple Products
# 3   Apple Products
# 4  Google Products
#
#                                                                                                                          text_tokenized
# 0                                  [have, 3g, iphone, after, hrs, tweeting, at, it, was, dead, need, to, upgrade, plugin, stations, at]
# 1  [know, about, awesome, ipad, iphone, app, that, you, ll, likely, appreciate, for, its, design, also, they, re, giving, free, ts, at]
# 2                                                                       [can, not, wait, for, also, they, should, sale, them, down, at]
# 3                                                            [hope, this, year, festival, isn, as, crashy, as, this, year, iphone, app]
# 4               [great, stuff, on, fri, marissa, mayer, google, tim, reilly, tech, books, conferences, amp, matt, mullenweg, wordpress]

# %%
df[['Company_Product','text_tokenized']][1973:2000]
# Out:
#       Company_Product  \
# 2009   Apple Products
# 2010  Google Products
# 2011   Apple Products
# 2012   Apple Products
# 2013   Apple Products
# 2014   Apple Products
# 2015   Apple Products
# 2017   Apple Products
# 2018   Apple Products
# 2019   Apple Products
# 2020   Apple Products
# 2021   Apple Products
# 2022  Google Products
# 2023  Google Products
# 2024  Google Products
# 2025   Apple Products
# 2026   Apple Products
# 2027  Google Products
# 2028  Google Products
# 2029   Apple Products
# 2030  Google Products
# 2031  Google Products
# 2032   Apple Products
# 2033   Apple Products
# 2034   Apple Products
# 2035   Apple Products
# 2036   Apple Products
#
#                                                                                                                                        text_tokenized
# 2009  [just, found, out, new, mapquest, iphone, app, has, turn, by, turn, gps, for, free, time, to, check, it, out, and, get, reacquainted, with, mq]
# 2010               [aha, found, proof, of, lactation, room, excuse, me, quot, mother, room, quot, brought, to, you, by, google, at, last, year, link]
# 2011                                               [makes, good, sense, rt, apple, set, to, open, popup, shop, in, core, of, sxsw, action, link, via]
# 2012                                                   [uber, brand, smart, gonna, move, ton, of, ipad2, opening, popup, shop, in, austin, for, link]
# 2013                                                                     [sounds, awesome, location, based, amp, could, be, incredibly, useful, link]
# 2014                                                                       [ipad, store, sold, out, of, everything, except, 64gig, wifi, only, white]
# 2015                                   [just, heard, that, apple, is, opening, store, in, downtown, austin, tomorrow, to, sell, ipads, to, attendees]
# 2017         [hah, found, the, quot, popup, quot, apple, store, where, the, ipad, will, be, on, sale, 2moro, gold, gym, at, 6th, and, congress, link]
# 2018                                                   [just, saved, the, so, productive, don, get, anything, done, with, my, ipad, dongle, get, get]
# 2019                                                                                     [just, found, the, back, door, into, the, apple, store, ftw]
# 2020            [almost, had, the, worst, fail, left, my, iphone, on, the, kitchen, counter, realized, it, after, min, of, driving, to, the, airport]
# 2021                                                  [don, need, to, charge, at, if, you, re, talking, in, the, sun, with, your, iphone, link, boom]
# 2022            [interested, to, hear, how, it, different, from, google, buzz, rt, get, ready, for, the, word, quot, circles, quot, to, be, trending]
# 2023     [just, had, to, read, tv, recaps, online, to, keep, up, with, my, shows, have, 600, unread, posts, in, google, reader, completely, detached]
# 2024                                                           [interested, to, see, what, google, will, have, to, show, off, when, they, unveil, at]
# 2025                                                  [so, annoyed, with, schedule, app, that, has, bad, for, ipad, my, fingers, ain, that, fat, all]
# 2026                                                                    [link, did, you, hear, apple, ûªs, opening, temporary, store, just, for, via]
# 2027                                                                                                   [html, and, you, at, the, google, booth, link]
# 2028                                                                       [don, hold, your, breath, about, google, circles, at, least, during, link]
# 2029                                   [stay, tuned, up, next, on, the, emergency, ipad, station, at, facebook, bullying, and, online, privacy, link]
# 2030                                                                     [now, poked, liked, and, re, tweeted, google, love, story, alisa, icrossing]
# 2031                                                           [ballroom, talking, about, some, cool, projects, obv, love, the, google, art, project]
# 2032                       [all, packed, charging, the, ipad, for, busy, day, weekend, ahead, also, need, to, download, the, apps, for, iphone, ipad]
# 2033                                                          [ipad, found, my, friend, jeff, has, it, thanks, to, everyone, who, helped, especially]
# 2034                  [all, packed, few, too, many, devices, alarm, set, for, 15am, see, ya, ll, at, psyched, to, meet, finally, many, of, you, guys]
# 2035                                                                                                   [why, should, shouldn, get, an, ipad, discuss]
# 2036                             [first, ipad2, sighting, at, interactive, infact, everyone, has, at, least, apple, product, in, use, at, all, times]

# %%
import re

def remove_numbers_and_special_patterns(text):
    # Combine all patterns into a single regex to remove numbers and special patterns
    pattern = r'^\d+[a-zA-Z]+' \
              r'|^[a-zA-Z]+\d+\d+$' \
              r'|^\d+(\.\d+)?$' \
              r'|^[a-zA-Z]+\d+[a-zA-Z]+$'\
              r'[^a-z\s#@]'
    
    
    # Remove the matched patterns and clean up spaces between letters
    cleaned_words = [re.sub(pattern, '',word ) for word in text]
    
    # Join the cleaned words back into a single string without spaces
    result = ' '.join(cleaned_words)
    
    return result

# Assuming 'df' is your DataFrame containing the 'text_tokenized' column with lists of words
df['text_tokenized'] = df['text_tokenized'].apply(remove_numbers_and_special_patterns)

# %%
df['text_tokenized'][1973:2000]
# Out:
# 2009    just found out new mapquest iphone app has turn by turn gps for free time to check it out and get reacquainted with mq
# 2010              aha found proof of lactation room excuse me quot mother room quot brought to you by google at last year link
# 2011                                          makes good sense rt apple set to open popup shop in core of sxsw action link via
# 2012                                            uber brand smart gonna move ton of ipad2 opening popup shop in austin for link
# 2013                                                         sounds awesome location based amp could be incredibly useful link
# 2014                                                                 ipad store sold out of everything except  wifi only white
# 2015                             just heard that apple is opening store in downtown austin tomorrow to sell ipads to attendees
# 2017                  hah found the quot popup quot apple store where the ipad will be on sale  gold gym at  and congress link
# 2018                                            just saved the so productive don get anything done with my ipad dongle get get
# 2019                                                                         just found the back door into the apple store ftw
# 2020           almost had the worst fail left my iphone on the kitchen counter realized it after min of driving to the airport
# 2021                                             don need to charge at if you re talking in the sun with your iphone link boom
# 2022           interested to hear how it different from google buzz rt get ready for the word quot circles quot to be trending
# 2023        just had to read tv recaps online to keep up with my shows have  unread posts in google reader completely detached
# 2024                                                   interested to see what google will have to show off when they unveil at
# 2025                                            so annoyed with schedule app that has bad for ipad my fingers ain that fat all
# 2026                                                          link did you hear apple ûªs opening temporary store just for via
# 2027                                                                                     html and you at the google booth link
# 2028                                                            don hold your breath about google circles at least during link
# 2029                             stay tuned up next on the emergency ipad station at facebook bullying and online privacy link
# 2030                                                          now poked liked and re tweeted google love story alisa icrossing
# 2031                                                 ballroom talking about some cool projects obv love the google art project
# 2032                    all packed charging the ipad for busy day weekend ahead also need to download the apps for iphone ipad
# 2033                                                 ipad found my friend jeff has it thanks to everyone who helped especially
# 2034                      all packed few too many devices alarm set for  see ya ll at psyched to meet finally many of you guys
# 2035                                                                                    why should shouldn get an ipad discuss
# 2036                        first ipad2 sighting at interactive infact everyone has at least apple product in use at all times
# Name: text_tokenized, dtype: object

# %%
df['text_tokenized'][2019]
# Out:
# 'just found the back door into the apple store ftw'

# %%
# Return the regex to lists
# Create new column with tokenized data
df["text_tokenized"] = df["text_tokenized"].apply(tokenizer.tokenize)
# Display full text
#df.style.set_properties(**{'text-align': 'left'})

# %%
df['text_tokenized'][2019]
# Out:
# ['just',
#  'found',
#  'the',
#  'back',
#  'door',
#  'into',
#  'the',
#  'apple',
#  'store',
#  'ftw']

# %%
#displaying 15 most common tokens
from nltk import FreqDist
tokens_count = [token for tokens in df["text_tokenized"] for token in tokens]
freq = FreqDist(tokens_count)
freq.most_common(50)
# Out:
# [('the', 3646),
#  ('link', 3022),
#  ('to', 2934),
#  ('at', 2595),
#  ('rt', 2329),
#  ('google', 2247),
#  ('ipad', 2172),
#  ('for', 2001),
#  ('apple', 1849),
#  ('in', 1606),
#  ('is', 1459),
#  ('of', 1427),
#  ('quot', 1414),
#  ('and', 1349),
#  ('store', 1317),
#  ('iphone', 1151),
#  ('up', 1112),
#  ('on', 1083),
#  ('new', 907),
#  ('it', 904),
#  ('you', 855),
#  ('an', 798),
#  ('my', 748),
#  ('austin', 721),
#  ('with', 706),
#  ('app', 618),
#  ('amp', 613),
#  ('launch', 579),
#  ('social', 555),
#  ('pop', 542),
#  ('circles', 519),
#  ('just', 504),
#  ('this', 493),
#  ('be', 488),
#  ('today', 485),
#  ('that', 465),
#  ('not', 437),
#  ('sxsw', 428),
#  ('from', 419),
#  ('out', 416),
#  ('network', 411),
#  ('by', 390),
#  ('have', 388),
#  ('your', 386),
#  ('are', 384),
#  ('line', 371),
#  ('will', 368),
#  ('about', 327),
#  ('via', 327),
#  ('called', 320)]

# %% [markdown]
# Before we proceed with further cleaning of the text, it is clear from the above results that stopwords dominated the texts and therefore need to be removed. It is also noted there are words such as "Link" that need to be investigated to determine whether it refers to a link to a website or something else. We will also check on the letters "rt"

# %%
text = df["text_tokenized"][1]
text
# Out:
# ['know',
#  'about',
#  'awesome',
#  'ipad',
#  'iphone',
#  'app',
#  'that',
#  'you',
#  'll',
#  'likely',
#  'appreciate',
#  'for',
#  'its',
#  'design',
#  'also',
#  'they',
#  're',
#  'giving',
#  'free',
#  'ts',
#  'at']

# %%
## Get the list of English stop words
stop_words = stopwords.words('english')
stop_words += list()
# Function to remove stop words
def remove_stop_words(tokens_list):
    """
    Removes stop words from a list of tokens.
    Arguments:
    - tokens_list: List of tokenized words.
    
    Returns:
    - List of tokens without stop words.
    """
    return [word for word in tokens_list if word.lower() not in stop_words]

# Apply the function to the tokenized text column
df["text_tokenized"] = df["text_tokenized"].apply(remove_stop_words)
df.head()
# Out:
#                                                                                                                                     tweet_text  \
# 0              .@wesley83 i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 1  @jessedee know about @fludapp ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at #sxsw
# 2                                                              @swonderlin can not wait for #ipad 2 also. they should sale them down at #sxsw.
# 3                                                           @sxsw i hope this year's festival isn't as crashy as this year's iphone app. #sxsw
# 4          @sxtxstate great stuff on fri #sxsw: marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
#
#                                                                                                         clean_tweet_text  \
# 0                    i have a 3g iphone. after 3 hrs tweeting at , it was dead!  i need to upgrade. plugin stations at .
# 1   know about  ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at
# 2                                                              can not wait for  2 also. they should sale them down at .
# 3                                                i hope this year's festival isn't as crashy as this year's iphone app.
# 4    great stuff on fri : marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
#
#   Tweet_Directed_at is_there_an_emotion_directed_at_a_brand_or_product  \
# 0            iPhone                                           Negative
# 1       iPhone iPad                                           Positive
# 2              iPad                                           Positive
# 3            iPhone                                           Negative
# 4            Google                                           Positive
#
#    Company_Product  \
# 0   Apple Products
# 1   Apple Products
# 2   Apple Products
# 3   Apple Products
# 4  Google Products
#
#                                                                                                         text_tokenized
# 0                                                       [iphone, hrs, tweeting, dead, need, upgrade, plugin, stations]
# 1                               [know, awesome, ipad, iphone, app, likely, appreciate, design, also, giving, free, ts]
# 2                                                                                                   [wait, also, sale]
# 3                                                                    [hope, year, festival, crashy, year, iphone, app]
# 4  [great, stuff, fri, marissa, mayer, google, tim, reilly, tech, books, conferences, amp, matt, mullenweg, wordpress]

# %%
#displaying 10 most common tokens
from nltk import FreqDist
tokens_count = [token for tokens in df["text_tokenized"] for token in tokens]
freq = FreqDist(tokens_count)
freq.most_common(50)
# Out:
# [('link', 3022),
#  ('rt', 2329),
#  ('google', 2247),
#  ('ipad', 2172),
#  ('apple', 1849),
#  ('quot', 1414),
#  ('store', 1317),
#  ('iphone', 1151),
#  ('new', 907),
#  ('austin', 721),
#  ('app', 618),
#  ('amp', 613),
#  ('launch', 579),
#  ('social', 555),
#  ('pop', 542),
#  ('circles', 519),
#  ('today', 485),
#  ('sxsw', 428),
#  ('network', 411),
#  ('line', 371),
#  ('via', 327),
#  ('called', 320),
#  ('get', 316),
#  ('android', 293),
#  ('one', 283),
#  ('major', 274),
#  ('party', 268),
#  ('like', 255),
#  ('temporary', 250),
#  ('opening', 249),
#  ('mobile', 247),
#  ('time', 228),
#  ('possibly', 216),
#  ('people', 211),
#  ('downtown', 211),
#  ('maps', 204),
#  ('free', 202),
#  ('day', 196),
#  ('popup', 194),
#  ('mayer', 189),
#  ('see', 185),
#  ('open', 184),
#  ('need', 172),
#  ('great', 172),
#  ('check', 172),
#  ('apps', 171),
#  ('marissa', 164),
#  ('going', 164),
#  ('go', 164),
#  ('ipad2', 162)]

# %%
# Search for rows where 'link' is in the tokenized text
matching_rows = df[df['text_tokenized'].apply(lambda tokens: 'link' in tokens)]

# Display the first 5 tweet texts where 'link' is found
print(matching_rows['tweet_text'].head(5))
# Out:
# 30                        attn: all  #sxsw frineds, @mention register for #gdgtlive  and see cobra iradar for android. {link}
# 33               at #sxsw.  oooh. rt @mention google to launch major new social network called circles, possibly today {link}
# 35      spin play - a new concept in music discovery for your ipad from @mention &amp; spin.com {link} #itunes #sxsw @mention
# 36    @mention  - false alarm: google circles not coming nowûòand probably not ever? - {link} #google #circles #social #sxsw
# 39                                                 mashable! - the ipad 2 takes over sxsw [video] #ipad #sxsw #gadgets {link}
# Name: tweet_text, dtype: object

# %%
# Search for rows where 'link' is in the tokenized text
matching_rows = df[df['text_tokenized'].apply(lambda tokens: 'rt' in tokens)]

# Display the first 5 tweet texts where 'link' is found
print(matching_rows['tweet_text'].head(5))
# Out:
# 7                               beautifully smart and simple idea rt @madebymany @thenextweb wrote about our #hollergram ipad app for #sxsw! http://bit.ly/ieavob
# 12                 gotta love this #sxsw google calendar featuring top parties/ show cases to check out.  rt @hamsandwich via @ischafer =&gt;http://bit.ly/axzwxb
# 18                                         must have #sxsw app! rt @malbonster: lovely review from forbes for our sxsw ipad app holler gram - http://t.co/g4gzypv
# 24    rt @laurieshook: i'm looking forward to the #smcdallas pre #sxsw party wed., and hoping i'll win an #ipad resulting from my shameless promotion.  #chevysmc
# 25                                                    rt haha, awesomely rad ipad app by @madebymany http://bit.ly/htdfim #hollergram #sxsw (via @michaelpiliero)
# Name: tweet_text, dtype: object

# %% [markdown]
# From the above we can see that the word link refers to URLS or HTTPs and the rt refers to retweet. This is not necessary for our analysis. Therefore, we will add to our stopwords list and remove them.

# %% [markdown]
# * After removing 'link' and 'rt', one can see a more refined group of words above.
# * From the results above we can already see ipad and google, apple being the most popular. The word 'quot' is also amongst the most popular. It raises more concern for further inspection. Check for the word 'quot' from the tweet section and try decipher what the word could mean. Then we can assess its importance in the analysis.
# * Also the word 'sxsw' as initially had started with '#' refers to the south by southwest conference. Remove this word; it is not significant in predicting negative, positive or neutral emotions.

# %%
# Search for rows where 'link' is in the tokenized text
matching_rows = df[df['text_tokenized'].apply(lambda tokens: 'quot' in tokens)]

# Display the first 5 tweet texts where 'link' is found
print(matching_rows['tweet_text'].head(10))
# Out:
# 34        the best!  rt @mention ha! first in line for #ipad2 at #sxsw &quot;pop-up&quot; apple store was an event planner #eventprofs #pcma #engage365
# 37     @mention  - great weather to greet you for #sxsw! still need a sweater at night..apple putting up &quot;flash store&quot; downtown to sell ipad2
# 45        khoi vinh (@mention says conde nast's headlong rush into ipad publishing was a &quot;fundamental misunderstanding&quot; of the platform #sxsw
# 47    {link} rt @mention &quot;google before you tweet&quot; is the new &quot;think before you speak.&quot; - mark belinsky, #911tweets panel at #sxsw.
# 52    #smile rt @mention i think apple's &quot;pop-up store&quot; in austin would be a lot more interesting if it actually, you know... popped up #sxsw
# 74                     new buzz? &quot;@mention google to launch major new social network called circles, possibly today {link} rt @mention #sxsw&quot;
# 75                              headline: &quot;#ipad 2 is the must-have gadget at #sxsw&quot; hmm... i could have seen that one coming! {link} #gadget
# 77                                                 know that &quot;dataviz&quot; translates to &quot;satanic&quot; on an iphone. i'm just sayin'. #sxsw
# 78                            .@mention &quot;google launched checkins a month ago.&quot; check ins are ok, but check outs are the future. #sxsw #bizzy
# 79              .@mention &quot;google launched checkins a month ago.&quot; check ins are ok, but check outs are the future. #sxsw #bizzy (via @mention
# Name: tweet_text, dtype: object

# %% [markdown]
# * From the above, the word "quot " in these Twitter texts appears to be part of an HTML entity reference for quotation marks: &quot;. In HTML, &quot;  represents a double quote ("), which is likely that the word "quot " could be a result of improper parsing or formatting when the content was processed. This is a reason enough to drop it by adding it to the stopwords list.

# %%
# Search for rows where 'link' is in the tokenized text
matching_rows = df[df['text_tokenized'].apply(lambda tokens: 'amp' in tokens)]

# Display the first 5 tweet texts where 'link' is found
print(matching_rows['tweet_text'].head(10))
# Out:
# 4                  @sxtxstate great stuff on fri #sxsw: marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
# 10                   find &amp; start impromptu parties at #sxsw with @hurricaneparty http://bit.ly/gvlrin i can't wait til the android app comes out.
# 23    really enjoying the changes in gowalla 3.0 for android! looking forward to seeing what else they &amp; foursquare have up their sleeves at #sxsw
# 35                               spin play - a new concept in music discovery for your ipad from @mention &amp; spin.com {link} #itunes #sxsw @mention
# 48                     {link} rt @mention 1st stop on the #sxsw #chaos &amp; @mention hunt: austin java. get in the spy game 4 a chance 2 win an ipad!
# 56                                  check out @mention @mention &amp; @mention in line for their ipad 2 in austin. power to them! #sxswi #sxsw  {link}
# 61                   ipad2? rt @mention droid &amp; mac here :) rt @mention my #agnerd confession, using laptop, ipad &amp; blackberry to follow #sxsw
# 69                                                        wonder if @mention &amp; @mention will be in the apple flashmob: tcrn.ch/fcs45j #sxsw #ipad2
# 72                                                          fast, fun &amp; future: @mention of google presenting at #sxsw on search, local and mobile
# 73                                      gsd&amp;m &amp; google's industry party tonight @mention - see u there! {link} #sxsw #austin #welivehere #gsdm
# Name: tweet_text, dtype: object

# %% [markdown]
# * The word "amp" in these Twitter texts is a result of the misinterpretation or encoding of the HTML entity &amp. It represents the ampersand (&) symbol. The entity &amp; is used in HTML to avoid conflicts with the actual & symbol, which has a special meaning in HTML code. Remove the word by adding it to the stop_words list.

# %%
# Add the words to the stop_words list.
stop_words += ['quot', 'sxsw', 'sxswi', 'amp', 'url', 'link', 'rt']

# %%
#Reapplying the function to remove stopwords with updated 'link' and 'rt'.
df["text_tokenized"] = df["text_tokenized"].apply(remove_stop_words)

# %%
#displaying 15 most common tokens
from nltk import FreqDist
tokens_count = [token for tokens in df["text_tokenized"] for token in tokens]
freq = FreqDist(tokens_count)
# Increase the number in the code below to verify removal
freq.most_common(20)
# Out:
# [('google', 2247),
#  ('ipad', 2172),
#  ('apple', 1849),
#  ('store', 1317),
#  ('iphone', 1151),
#  ('new', 907),
#  ('austin', 721),
#  ('app', 618),
#  ('launch', 579),
#  ('social', 555),
#  ('pop', 542),
#  ('circles', 519),
#  ('today', 485),
#  ('network', 411),
#  ('line', 371),
#  ('via', 327),
#  ('called', 320),
#  ('get', 316),
#  ('android', 293),
#  ('one', 283)]

# %% [markdown]
# Proceed to lematization : Lematization is prefered to stemming because it is reduces a word to its base or root form (lemma) based on its linguistic meaning and context and not like stemming which reduces a word to its root form by stripping affixes, without considering linguistic context.

# %%
# Apply lemmatization to the 'text_tokenized' column
# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

# Function to lemmatize tokens
def lemmatize_tokens(tokens):
    return [lemmatizer.lemmatize(token) for token in tokens]

# Apply lemmatization to the 'text_tokenized' column
df['text_tokenized_lemmatized'] = df['text_tokenized'].apply(lemmatize_tokens)

# %%
#displaying 15 most common tokens
from nltk import FreqDist
tokens_count = [token for tokens in df['text_tokenized_lemmatized'] for token in tokens]
freq = FreqDist(tokens_count)
# Increase the number in the code below to verify removal
freq.most_common(15)
# Out:
# [('google', 2248),
#  ('ipad', 2172),
#  ('apple', 1852),
#  ('store', 1352),
#  ('iphone', 1151),
#  ('new', 907),
#  ('austin', 722),
#  ('app', 618),
#  ('launch', 606),
#  ('social', 555),
#  ('pop', 545),
#  ('circle', 533),
#  ('today', 485),
#  ('network', 418),
#  ('line', 402)]

# %%
df['text_tokenized_lemmatized'][5:15]
# Out:
# 5                                  [new, ipad, apps, communication, showcased, conference]
# 6                             [starting, around, corner, hop, skip, jump, good, time, fan]
# 7                                     [beautifully, smart, simple, idea, wrote, ipad, app]
# 8                [counting, day, plus, strong, canadian, dollar, mean, stock, apple, gear]
# 9                           [excited, meet, show, sprint, galaxy, still, running, android]
# 10                          [find, start, impromptu, party, wait, til, android, app, come]
# 11    [foursquare, ups, game, time, still, prefer, far, best, looking, android, app, date]
# 12      [gotta, love, google, calendar, featuring, top, party, show, case, check, via, gt]
# 13                                                                      [great, ipad, app]
# 14                                                       [haha, awesomely, rad, ipad, app]
# Name: text_tokenized_lemmatized, dtype: object

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS
# ##### 1. Looking at the most popular words
# ##### 2. Looking at popular words tied to positive emotion
# ##### 3. Looking at popular words tired to negative emotion
# ##### 4. Distribution of positive , negative and neutral emotion for both Apple and Google
# ##### 5. Looking at distribution of words tired to Apple and Google
# ##### 6. Looking at how Apple and Google is tired to a positive emotion
# ##### 7. Looking at how Apple and Google is tired to a negative emotion

# %%
# Filter the dataframe to capture only the positive comments
df_positive = df[df['is_there_an_emotion_directed_at_a_brand_or_product'] == 'Positive']
#Again filter the df_positive dataframe for apple products
df_pos_Apple = df_positive[df_positive['Company_Product'] == 'Apple Products']
df_pos_Google = df_positive[df_positive['Company_Product'] == 'Google Products' ]
# Uncoment below to Display few rows
# df_pos_Google.head()
# df_pos_Apple.head()

# %% [markdown]
# Create a function that we call nd returns the word clouds for specified data set.
# The function takes in the tokenized column and displays the word cloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

#defining a function for wordcloud generation
def generate_wordcloud(tokens, collocations=False, background_color='black', 
                       colormap='Greens', display=True):
    
    """Function generates and returns a wordcloud based on a tokens list passed in.
    -------------------------------
    Arguments:
    tokens: a tokens list
    collocations: Whether to include collocations (bigrams) of two words
    background_color: background color of the resulting word cloud
    colormap: the color map for the words that will be in the word cloud
    display: Whether to show the resulting wordcloud"""
    
    ## Initalize a WordCloud
    wordcloud = WordCloud(collocations=collocations, 
                          background_color=background_color, 
                          colormap=colormap, 
                          width=500, height=300)

    ## Generate wordcloud from tokens
    wordcloud.generate(' '.join(tokens))

    ## Plot with matplotlib
    if display:
        plt.figure(figsize = (12, 15), facecolor = None) 
        plt.imshow(wordcloud) 
        plt.axis('off');
    return wordcloud

# %%
# Looking at the top 10 most popular words, @user_accounts and hashtags
# 25 Most popular words

from nltk import FreqDist
tokens_count = [token for tokens in df_pos_Apple['text_tokenized_lemmatized'] for token in tokens]
freq = FreqDist(tokens_count)
freq.most_common(10)
# Out:
# [('ipad', 918),
#  ('apple', 742),
#  ('store', 535),
#  ('iphone', 423),
#  ('app', 278),
#  ('austin', 227),
#  ('pop', 209),
#  ('new', 206),
#  ('one', 135),
#  ('line', 134)]

# %% [markdown]
# * From the most frequent words in the freqDist above, we see the names of company products as the most positive popular words. We eliminate them so that we can only display words that could closely capture the emotion attributed to the product. Ipad, apple, iphone and app recieved the most positive feedbacks . We remove these products by adding them to the list of stopwords

# %%
# Add the words to the stop_words list.
stop_words += [
   'ipad',
   'apple',
   'iphone',
    'app', 'google', 'store', 'ipad2'
]

# %%
# Apply the function to the tokenized text column
df_pos_Apple['text_tokenized_lemmatized'] = df_pos_Apple['text_tokenized_lemmatized'].apply(remove_stop_words)
# Out:
# <ipython-input-488-7aae959af8fc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pos_Apple['text_tokenized_lemmatized'] = df_pos_Apple['text_tokenized_lemmatized'].apply(remove_stop_words)

# %%
# Looking at the top 10 most popular words, @user_accounts and hashtags
# 25 Most popular words
from nltk import FreqDist
tokens_count = [token for tokens in df_pos_Apple['text_tokenized_lemmatized'] for token in tokens]
freq = FreqDist(tokens_count)
freq.most_common(10)
# Out:
# [('austin', 227),
#  ('pop', 209),
#  ('new', 206),
#  ('one', 135),
#  ('line', 134),
#  ('get', 131),
#  ('via', 99),
#  ('win', 95),
#  ('cool', 93),
#  ('go', 88)]

# %%
tokens_pos_ls =  df_pos_Apple['text_tokenized_lemmatized']
tokens_pos_ls_flat = [item for sublist in tokens_pos_ls for item in sublist]
tokens_pos_ls
# Out:
# 1                 [know, awesome, likely, appreciate, design, also, giving, free]
# 2                                                              [wait, also, sale]
# 7                                       [beautifully, smart, simple, idea, wrote]
# 8              [counting, day, plus, strong, canadian, dollar, mean, stock, gear]
# 13                                                                        [great]
#                                           ...
# 7415                                      [case, rad, ready, stop, tomorrow, get]
# 7420                          [pr, guy, convinced, switch, back, great, coverage]
# 7421                                    [papyrus, sort, like, nice, lol, lavelle]
# 7426    [always, used, camera, image, stabilizer, mode, suggestion, cam, feature]
# 7429                                                                 [everywhere]
# Name: text_tokenized_lemmatized, Length: 2054, dtype: object

# %%
#generating word cloud
cloud_pos_w_company = generate_wordcloud(tokens_pos_ls_flat, collocations=True)

# %% [markdown]
# **Mention of the most positive word**

# %%
# Looking at the top 10 most popular words, @user_accounts and hashtags
# 25 Most popular words

from nltk import FreqDist
tokens_count = [token for tokens in df_pos_Google['text_tokenized_lemmatized'] for token in tokens]
freq = FreqDist(tokens_count)
freq.most_common(20)
# Out:
# [('google', 650),
#  ('new', 131),
#  ('android', 114),
#  ('party', 110),
#  ('map', 109),
#  ('circle', 105),
#  ('social', 101),
#  ('launch', 85),
#  ('network', 84),
#  ('mayer', 67),
#  ('mobile', 67),
#  ('app', 66),
#  ('today', 62),
#  ('called', 60),
#  ('marissa', 59),
#  ('great', 57),
#  ('major', 54),
#  ('time', 52),
#  ('user', 44),
#  ('possibly', 41)]

# %%
# adding to the stopwords
# Add the words to the stop_words list.
stop_words += ['google', 'android']

# %%
# Apply the function to the tokenized text column
df_pos_Google['text_tokenized_lemmatized'] = df_pos_Google['text_tokenized_lemmatized'].apply(remove_stop_words)
# Out:
# <ipython-input-494-c18a9a0d8bab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pos_Google['text_tokenized_lemmatized'] = df_pos_Google['text_tokenized_lemmatized'].apply(remove_stop_words)

# %%
# Looking at the top 10 most popular words, @user_accounts and hashtags
# 25 Most popular words

from nltk import FreqDist
tokens_count = [token for tokens in df_pos_Google['text_tokenized_lemmatized'] for token in tokens]
freq = FreqDist(tokens_count)
freq.most_common(10)
# Out:
# [('new', 131),
#  ('party', 110),
#  ('map', 109),
#  ('circle', 105),
#  ('social', 101),
#  ('launch', 85),
#  ('network', 84),
#  ('mayer', 67),
#  ('mobile', 67),
#  ('today', 62)]

# %%
tokens_pos_Go =  df_pos_Google['text_tokenized_lemmatized']
tokens_pos_Go_flat = [item for sublist in tokens_pos_Go  for item in sublist]

# %%
#generating word cloud
cloud_pos_w_company = generate_wordcloud(tokens_pos_Go_flat, collocations=True)

# %% [markdown]
# #### Negative Emotions

# %%
# Filter the dataframe to capture only the positive comments
df_negative = df[df['is_there_an_emotion_directed_at_a_brand_or_product'] == 'Negative']
#Again filter the df_negative dataframe for apple products
df_neg_Apple = df_negative[df_negative['Company_Product'] == 'Apple Products']
df_neg_Google = df_negative[df_negative['Company_Product'] == 'Google Products']

# %%
# Looking at the top 10 most popular words, @user_accounts and hashtags
# 25 Most popular words

from nltk import FreqDist
tokens_count = [token for tokens in df_neg_Apple['text_tokenized_lemmatized'] for token in tokens]
freq = FreqDist(tokens_count)
freq.most_common(20)
# Out:
# [('ipad', 175),
#  ('iphone', 145),
#  ('apple', 106),
#  ('app', 51),
#  ('store', 47),
#  ('like', 36),
#  ('design', 29),
#  ('austin', 25),
#  ('people', 24),
#  ('need', 22),
#  ('line', 22),
#  ('new', 22),
#  ('apps', 21),
#  ('one', 21),
#  ('think', 18),
#  ('look', 18),
#  ('headache', 17),
#  ('news', 17),
#  ('battery', 17),
#  ('pop', 17)]

# %%
# adding to the stopwords
# Add the words to the stop_words list.
stop_words += ['ipad', 'iphone', 'apple', 'app','store']

# %%
# Apply the function to the tokenized text column
df_neg_Apple['text_tokenized_lemmatized'] = df_neg_Apple['text_tokenized_lemmatized'].apply(remove_stop_words)
# Out:
# <ipython-input-501-1e4268896d12>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_neg_Apple['text_tokenized_lemmatized'] = df_neg_Apple['text_tokenized_lemmatized'].apply(remove_stop_words)

# %%
# Looking at the top 10 most popular words, @user_accounts and hashtags
# 25 Most popular words

from nltk import FreqDist
tokens_count = [token for tokens in df_neg_Apple['text_tokenized_lemmatized'] for token in tokens]
freq = FreqDist(tokens_count)
freq.most_common()
# Out:
# [('like', 36),
#  ('design', 29),
#  ('austin', 25),
#  ('people', 24),
#  ('need', 22),
#  ('line', 22),
#  ('new', 22),
#  ('apps', 21),
#  ('one', 21),
#  ('think', 18),
#  ('look', 18),
#  ('headache', 17),
#  ('news', 17),
#  ('battery', 17),
#  ('pop', 17),
#  ('time', 17),
#  ('day', 17),
#  ('get', 16),
#  ('would', 16),
#  ('say', 15),
#  ('america', 15),
#  ('go', 14),
#  ('thing', 14),
#  ('long', 14),
#  ('fascist', 14),
#  ('company', 14),
#  ('year', 13),
#  ('back', 13),
#  ('money', 13),
#  ('phone', 13),
#  ('fast', 12),
#  ('take', 12),
#  ('going', 11),
#  ('via', 11),
#  ('good', 11),
#  ('see', 11),
#  ('already', 10),
#  ('hate', 10),
#  ('heard', 10),
#  ('best', 10),
#  ('gave', 10),
#  ('nothing', 10),
#  ('fade', 10),
#  ('talk', 10),
#  ('every', 10),
#  ('come', 9),
#  ('still', 9),
#  ('want', 9),
#  ('even', 9),
#  ('really', 9),
#  ('classiest', 9),
#  ('novelty', 9),
#  ('among', 9),
#  ('delegate', 9),
#  ('button', 9),
#  ('many', 8),
#  ('user', 8),
#  ('know', 8),
#  ('mobile', 8),
#  ('wait', 8),
#  ('blackberry', 8),
#  ('tweet', 8),
#  ('relief', 8),
#  ('content', 8),
#  ('guy', 8),
#  ('getting', 8),
#  ('everyone', 8),
#  ('life', 8),
#  ('digital', 8),
#  ('call', 8),
#  ('yet', 8),
#  ('swisher', 8),
#  ('weekend', 7),
#  ('hour', 7),
#  ('suck', 7),
#  ('first', 7),
#  ('twitter', 7),
#  ('much', 7),
#  ('elegant', 7),
#  ('made', 7),
#  ('photo', 7),
#  ('taking', 7),
#  ('session', 7),
#  ('kara', 7),
#  ('someone', 7),
#  ('tweeting', 6),
#  ('morning', 6),
#  ('last', 6),
#  ('pretty', 6),
#  ('give', 6),
#  ('update', 6),
#  ('barry', 6),
#  ('diller', 6),
#  ('use', 6),
#  ('may', 6),
#  ('well', 6),
#  ('two', 6),
#  ('tablet', 6),
#  ('make', 6),
#  ('love', 6),
#  ('buy', 6),
#  ('way', 6),
#  ('note', 6),
#  ('got', 6),
#  ('room', 6),
#  ('instead', 6),
#  ('hope', 5),
#  ('coming', 5),
#  ('panel', 5),
#  ('also', 5),
#  ('stupid', 5),
#  ('temporary', 5),
#  ('let', 5),
#  ('technology', 5),
#  ('ever', 5),
#  ('might', 5),
#  ('guess', 5),
#  ('job', 5),
#  ('worst', 5),
#  ('god', 5),
#  ('macbook', 5),
#  ('enough', 5),
#  ('else', 5),
#  ('laptop', 5),
#  ('around', 5),
#  ('today', 5),
#  ('camera', 5),
#  ('douche', 5),
#  ('part', 5),
#  ('working', 5),
#  ('using', 5),
#  ('weird', 5),
#  ('expect', 5),
#  ('live', 5),
#  ('sun', 5),
#  ('ridiculous', 5),
#  ('forward', 5),
#  ('yes', 5),
#  ('upgrade', 4),
#  ('late', 4),
#  ('next', 4),
#  ('crash', 4),
#  ('used', 4),
#  ('temp', 4),
#  ('fucking', 4),
#  ('cool', 4),
#  ('bad', 4),
#  ('trying', 4),
#  ('thanks', 4),
#  ('daily', 4),
#  ('seems', 4),
#  ('better', 4),
#  ('stream', 4),
#  ('hey', 4),
#  ('feel', 4),
#  ('help', 4),
#  ('read', 4),
#  ('walking', 4),
#  ('holding', 4),
#  ('open', 4),
#  ('big', 4),
#  ('work', 4),
#  ('great', 4),
#  ('release', 4),
#  ('drive', 4),
#  ('fix', 4),
#  ('never', 4),
#  ('product', 4),
#  ('ppl', 4),
#  ('shit', 4),
#  ('microsoft', 4),
#  ('bit', 4),
#  ('io', 4),
#  ('screen', 4),
#  ('always', 4),
#  ('fail', 4),
#  ('away', 4),
#  ('autocorrect', 4),
#  ('tried', 4),
#  ('hand', 4),
#  ('white', 4),
#  ('ipads', 4),
#  ('ad', 4),
#  ('anything', 4),
#  ('glad', 4),
#  ('heat', 4),
#  ('million', 4),
#  ('cashmore', 4),
#  ('tech', 4),
#  ('right', 4),
#  ('mistake', 4),
#  ('worth', 4),
#  ('burn', 4),
#  ('ûó', 4),
#  ('existence', 4),
#  ('support', 4),
#  ('dead', 3),
#  ('charger', 3),
#  ('lost', 3),
#  ('schedule', 3),
#  ('city', 3),
#  ('block', 3),
#  ('pic', 3),
#  ('alarm', 3),
#  ('flight', 3),
#  ('behind', 3),
#  ('geolocation', 3),
#  ('texas', 3),
#  ('concept', 3),
#  ('opening', 3),
#  ('launch', 3),
#  ('oh', 3),
#  ('interactive', 3),
#  ('conference', 3),
#  ('idea', 3),
#  ('power', 3),
#  ('v', 3),
#  ('follow', 3),
#  ('ipad2s', 3),
#  ('find', 3),
#  ('brick', 3),
#  ('thought', 3),
#  ('lot', 3),
#  ('book', 3),
#  ('gt', 3),
#  ('û_', 3),
#  ('cont', 3),
#  ('trend', 3),
#  ('audience', 3),
#  ('waiting', 3),
#  ('point', 3),
#  ('guide', 3),
#  ('hotel', 3),
#  ('brilliant', 3),
#  ('deal', 3),
#  ('wifi', 3),
#  ('selling', 3),
#  ('check', 3),
#  ('far', 3),
#  ('could', 3),
#  ('booth', 3),
#  ('includes', 3),
#  ('uberguide', 3),
#  ('useful', 3),
#  ('hmm', 3),
#  ('tweetdeck', 3),
#  ('mean', 3),
#  ('heading', 3),
#  ('mac', 3),
#  ('web', 3),
#  ('believe', 3),
#  ('explanation', 3),
#  ('survival', 3),
#  ('lol', 3),
#  ('group', 3),
#  ('deleting', 3),
#  ('charge', 3),
#  ('nyt', 3),
#  ('amazing', 3),
#  ('fuck', 3),
#  ('us', 3),
#  ('sell', 3),
#  ('steve', 3),
#  ('official', 3),
#  ('true', 3),
#  ('approach', 3),
#  ('tip', 3),
#  ('put', 3),
#  ('film', 3),
#  ('five', 3),
#  ('magic', 3),
#  ('stuff', 3),
#  ('reporting', 3),
#  ('hear', 3),
#  ('almost', 3),
#  ('sold', 3),
#  ('walk', 3),
#  ('watched', 3),
#  ('person', 3),
#  ('non', 3),
#  ('tomorrow', 3),
#  ('run', 3),
#  ('happen', 3),
#  ('interesting', 3),
#  ('u', 3),
#  ('building', 3),
#  ('netflix', 3),
#  ('awesome', 3),
#  ('josh', 3),
#  ('clark', 3),
#  ('dear', 3),
#  ('error', 3),
#  ('peter', 3),
#  ('minor', 3),
#  ('improvement', 3),
#  ('unless', 3),
#  ('autocorrects', 3),
#  ('continued', 3),
#  ('anyone', 3),
#  ('delicious', 3),
#  ('struggle', 3),
#  ('hipster', 3),
#  ('source', 3),
#  ('code', 3),
#  ('half', 3),
#  ('hr', 2),
#  ('plugin', 2),
#  ('station', 2),
#  ('festival', 2),
#  ('crashy', 2),
#  ('sunday', 2),
#  ('insane', 2),
#  ('changed', 2),
#  ('sync', 2),
#  ('spent', 2),
#  ('seen', 2),
#  ('terrible', 2),
#  ('missed', 2),
#  ('meant', 2),
#  ('found', 2),
#  ('kyping', 2),
#  ('releasing', 2),
#  ('background', 2),
#  ('patch', 2),
#  ('built', 2),
#  ('traffic', 2),
#  ('mall', 2),
#  ('crowded', 2),
#  ('genius', 2),
#  ('overheard', 2),
#  ('arg', 2),
#  ('show', 2),
#  ('leaf', 2),
#  ('busy', 2),
#  ('keep', 2),
#  ('attention', 2),
#  ('shipment', 2),
#  ('japan', 2),
#  ('came', 2),
#  ('tell', 2),
#  ('feeling', 2),
#  ('try', 2),
#  ('search', 2),
#  ('auto', 2),
#  ('week', 2),
#  ('word', 2),
#  ('remember', 2),
#  ('ha', 2),
#  ('addict', 2),
#  ('fan', 2),
#  ('sharing', 2),
#  ('opinion', 2),
#  ('listen', 2),
#  ('tx', 2),
#  ('subscription', 2),
#  ('data', 2),
#  ('biggest', 2),
#  ('success', 2),
#  ('shop', 2),
#  ('lt', 2),
#  ('spend', 2),
#  ('left', 2),
#  ('rule', 2),
#  ('ooing', 2),
#  ('ahing', 2),
#  ('everybody', 2),
#  ('internet', 2),
#  ('lord', 2),
#  ('vortex', 2),
#  ('smugness', 2),
#  ('unbearable', 2),
#  ('went', 2),
#  ('typing', 2),
#  ('finger', 2),
#  ('lame', 2),
#  ('software', 2),
#  ('download', 2),
#  ('luck', 2),
#  ('crazy', 2),
#  ('outlet', 2),
#  ('started', 2),
#  ('lying', 2),
#  ('signal', 2),
#  ('strength', 2),
#  ('hootsuite', 2),
#  ('useless', 2),
#  ('disaster', 2),
#  ('brand', 2),
#  ('makeshift', 2),
#  ('sense', 2),
#  ('kawasaki', 2),
#  ('groupme', 2),
#  ('agree', 2),
#  ('bc', 2),
#  ('lonely', 2),
#  ('planet', 2),
#  ('free', 2),
#  ('cluttering', 2),
#  ('handset', 2),
#  ('stop', 2),
#  ('major', 2),
#  ('cant', 2),
#  ('checking', 2),
#  ('touch', 2),
#  ('running', 2),
#  ('cake', 2),
#  ('putting', 2),
#  ('write', 2),
#  ('respect', 2),
#  ('interface', 2),
#  ('metaphor', 2),
#  ('another', 2),
#  ('window', 2),
#  ('voluntarily', 2),
#  ('greatest', 2),
#  ('collection', 2),
#  ('egomaniac', 2),
#  ('history', 2),
#  ('haha', 2),
#  ('dream', 2),
#  ('mostly', 2),
#  ('old', 2),
#  ('excited', 2),
#  ('awareness', 2),
#  ('crashed', 2),
#  ('stay', 2),
#  ('switch', 2),
#  ('world', 2),
#  ('disappointed', 2),
#  ('fest', 2),
#  ('fellow', 2),
#  ('festgoers', 2),
#  ('etc', 2),
#  ('srsly', 2),
#  ('disney', 2),
#  ('change', 2),
#  ('coworkers', 2),
#  ('visigoth', 2),
#  ('com', 2),
#  ('compatible', 2),
#  ('maybe', 2),
#  ('lb', 2),
#  ('charging', 2),
#  ('social', 2),
#  ('walked', 2),
#  ('outside', 2),
#  ('iphones', 2),
#  ('staying', 2),
#  ('game', 2),
#  ('survive', 2),
#  ('self', 2),
#  ('downside', 2),
#  ('mocked', 2),
#  ('friend', 2),
#  ('stopped', 2),
#  ('taxi', 2),
#  ('cab', 2),
#  ('ballroom', 2),
#  ('nice', 2),
#  ('gps', 2),
#  ('stuck', 2),
#  ('panelist', 2),
#  ('sustainability', 2),
#  ('space', 2),
#  ('pay', 2),
#  ('downloads', 2),
#  ('aron', 2),
#  ('pilhofer', 2),
#  ('khoi', 2),
#  ('vinh', 2),
#  ('forgotten', 2),
#  ('figure', 2),
#  ('navigating', 2),
#  ('dy', 2),
#  ('malady', 2),
#  ('elbow', 2),
#  ('home', 2),
#  ('clock', 2),
#  ('popup', 2),
#  ('drowning', 2),
#  ('droid', 2),
#  ('sigh', 2),
#  ('man', 2),
#  ('real', 2),
#  ('broken', 2),
#  ('cannot', 2),
#  ('concert', 2),
#  ('issue', 2),
#  ('hack', 2),
#  ('farmer', 2),
#  ('keyboard', 2),
#  ('roaming', 2),
#  ('mad', 2),
#  ('different', 2),
#  ('area', 2),
#  ('filter', 2),
#  ('slide', 2),
#  ('panned', 2),
#  ('trumping', 2),
#  ('rightfully', 2),
#  ('cost', 2),
#  ('called', 2),
#  ('proof', 2),
#  ('kinda', 2),
#  ('minute', 2),
#  ('website', 2),
#  ('handle', 2),
#  ('fly', 2),
#  ('corporation', 2),
#  ('rate', 2),
#  ('experience', 2),
#  ('disagree', 2),
#  ('please', 2),
#  ('hashtags', 2),
#  ('ûªs', 2),
#  ('single', 2),
#  ('epic', 2),
#  ('nerd', 2),
#  ('wanted', 2),
#  ('nokia', 2),
#  ('agreed', 2),
#  ('door', 2),
#  ('decided', 2),
#  ('la', 2),
#  ('ogilvy', 2),
#  ('idiocy', 2),
#  ('janecek', 2),
#  ('charity', 2),
#  ('decision', 2),
#  ('effing', 2),
#  ('hubby', 2),
#  ('towards', 2),
#  ('wife', 2),
#  ('number', 2),
#  ('newest', 2),
#  ('unstable', 2),
#  ('saw', 2),
#  ('picture', 2),
#  ('journalsim', 2),
#  ('democracy', 2),
#  ('informed', 2),
#  ('populous', 2),
#  ('focus', 2),
#  ('high', 2),
#  ('night', 2),
#  ('obviously', 2),
#  ('shell', 2),
#  ('looking', 2),
#  ('cut', 2),
#  ('wow', 2),
#  ('message', 2),
#  ('device', 2),
#  ('plus', 2),
#  ('turn', 2),
#  ('anyway', 2),
#  ('sure', 2),
#  ('noticed', 1),
#  ('dst', 1),
#  ('attending', 1),
#  ('provide', 1),
#  ('mind', 1),
#  ('dataviz', 1),
#  ('translates', 1),
#  ('satanic', 1),
#  ('sayin', 1),
#  ('seriously', 1),
#  ('testing', 1),
#  ('constant', 1),
#  ('causing', 1),
#  ('wp7', 1),
#  ('conflagration', 1),
#  ('doofusness', 1),
#  ('couple', 1),
#  ('wild', 1),
#  ('botch', 1),
#  ('timechange', 1),
#  ('er', 1),
#  ('freak', 1),
#  ('bloody', 1),
#  ('mary', 1),
#  ('wish', 1),
#  ('course', 1),
#  ('understand', 1),
#  ('corralling', 1),
#  ('cattle', 1),
#  ('downtown', 1),
#  ('yay', 1),
#  ('fake', 1),
#  ('dongle', 1),
#  ('mdw', 1),
#  ('second', 1),
#  ('halfway', 1),
#  ('boarded', 1),
#  ('plane', 1),
#  ('q', 1),
#  ('process', 1),
#  ('poo', 1),
#  ('poos', 1),
#  ('early', 1),
#  ('creative', 1),
#  ('balance', 1),
#  ('quick', 1),
#  ('airplane', 1),
#  ('mode', 1),
#  ('desperate', 1),
#  ('secret', 1),
#  ('batphone', 1),
#  ('nut', 1),
#  ('docomo', 1),
#  ('introduced', 1),
#  ('six', 1),
#  ('jeez', 1),
#  ('dunno', 1),
#  ('gold', 1),
#  ('gym', 1),
#  ('realize', 1),
#  ('un', 1),
#  ('aesthetic', 1),
#  ('inane', 1),
#  ('surely', 1),
#  ('southby', 1),
#  ('full', 1),
#  ('underway', 1),
#  ('intermittent', 1),
#  ('bout', 1),
#  ('donating', 1),
#  ('spending', 1),
#  ('place', 1),
#  ('touched', 1),
#  ('hmmzies', 1),
#  ('exist', 1),
#  ('pulling', 1),
#  ('antique', 1),
#  ('everytime', 1),
#  ('shoot', 1),
#  ('display', 1),
#  ('result', 1),
#  ('question', 1),
#  ('later', 1),
#  ('mocking', 1),
#  ('disliking', 1),
#  ('shortening', 1),
#  ('overheating', 1),
#  ('british', 1),
#  ('sounding', 1),
#  ('wilting', 1),
#  ('stress', 1),
#  ('tough', 1),
#  ('dwindling', 1),
#  ('jeebus', 1),
#  ('correcting', 1),
#  ('curse', 1),
#  ('imac', 1),
#  ('staring', 1),
#  ('kicked', 1),
#  ('bucket', 1),
#  ('heck', 1),
#  ('within', 1),
#  ('distance', 1),
#  ('unequipped', 1),
#  ('compared', 1),
#  ('dang', 1),
#  ('teeming', 1),
#  ('sea', 1),
#  ('twittering', 1),
#  ('engage', 1),
#  ('anoth', 1),
#  ('tomlinson', 1),
#  ('observer', 1),
#  ('impediment', 1),
#  ('packing', 1),
#  ('showing', 1),
#  ('fragmentation', 1),
#  ('pocket', 1),
#  ('cope', 1),
#  ('usability', 1),
#  ('marketer', 1),
#  ('medium', 1),
#  ('professional', 1),
#  ('save', 1),
#  ('connect', 1),
#  ('though', 1),
#  ('computer', 1),
#  ('suggestion', 1),
#  ('dangerous', 1),
#  ('whole', 1),
#  ('ftp', 1),
#  ('cloudapp', 1),
#  ('skype', 1),
#  ('carry', 1),
#  ('smell', 1),
#  ('thank', 1),
#  ('letting', 1),
#  ('test', 1),
#  ('car', 1),
#  ('weve', 1),
#  ('talked', 1),
#  ('heyo', 1),
#  ('ridic', 1),
#  ('wonder', 1),
#  ('mexico', 1),
#  ('def', 1),
#  ('sorta', 1),
#  ('sux', 1),
#  ('cocky', 1),
#  ('perhaps', 1),
#  ('separate', 1),
#  ('extra', 1),
#  ('marketing', 1),
#  ('disgusted', 1),
#  ('pm', 1),
#  ('strong', 1),
#  ('corrupted', 1),
#  ('au', 1),
#  ('bergstrom', 1),
#  ('midday', 1),
#  ('mid', 1),
#  ('blocked', 1),
#  ('immobile', 1),
#  ('serf', 1),
#  ('purpose', 1),
#  ('taunt', 1),
#  ('xipad', 1),
#  ('shite', 1),
#  ('sponso', 1),
#  ('nexus', 1),
#  ('iphone4', 1),
#  ('paper', 1),
#  ('likely', 1),
#  ('avoiding', 1),
#  ('pitfall', 1),
#  ('challenge', 1),
#  ('died', 1),
#  ('middle', 1),
#  ('function', 1),
#  ('march', 1),
#  ('pst', 1),
#  ('batt', 1),
#  ('selfish', 1),
#  ('served', 1),
#  ('cwebb', 1),
#  ('grant', 1),
#  ('hill', 1),
#  ('limit', 1),
#  ('specific', 1),
#  ('platform', 1),
#  ('interview', 1),
#  ('continuous', 1),
#  ('approval', 1),
#  ('woe', 1),
#  ('quite', 1),
#  ('grumbling', 1),
#  ('feature', 1),
#  ('v2', 1),
#  ('nfc', 1),
#  ('standardization', 1),
#  ('rear', 1),
#  ('facing', 1),
#  ('loading', 1),
#  ('draining', 1),
#  ('cancel', 1),
#  ('project', 1),
#  ('manager', 1),
#  ('queue', 1),
#  ('spell', 1),
#  ('without', 1),
#  ('correct', 1),
#  ('must', 1),
#  ('load', 1),
#  ('site', 1),
#  ('feelin', 1),
#  ('lowest', 1),
#  ('possible', 1),
#  ('brightness', 1),
#  ('basic', 1),
#  ('flash', 1),
#  ('discussion', 1),
#  ('relevant', 1),
#  ('wsj', 1),
#  ('ask', 1),
#  ('future', 1),
#  ('branded', 1),
#  ('native', 1),
#  ('usage', 1),
#  ('quotable', 1),
#  ('board', 1),
#  ('somebody', 1),
#  ('consistently', 1),
#  ('type', 1),
#  ('goddamn', 1),
#  ('jump', 1),
#  ('calendar', 1),
#  ('frankeninterface', 1),
#  ('designed', 1),
#  ('suicidal', 1),
#  ('chinese', 1),
#  ('launched', 1),
#  ('vintage', 1),
#  ('format', 1),
#  ('ipod', 1),
#  ('snarky', 1),
#  ('employee', 1),
#  ('ah', 1),
#  ('important', 1),
#  ('pen', 1),
#  ('insidious', 1),
#  ('disgraceful', 1),
#  ('bldg', 1),
#  ('appstore', 1),
#  ('wholistic', 1),
#  ('mktg', 1),
#  ('strategy', 1),
#  ('adoption', 1),
#  ('rely', 1),
#  ('composed', 1),
#  ('acerbic', 1),
#  ('cynical', 1),
#  ('dumped', 1),
#  ('flaw', 1),
#  ('annoyed', 1),
#  ('fat', 1),
#  ('forbidden', 1),
#  ('spoiled', 1),
#  ('rocking', 1),
#  ('overlapping', 1),
#  ('example', 1),
#  ('promo', 1),
#  ('excludes', 1),
#  ('esp', 1),
#  ('since', 1),
#  ('insists', 1),
#  ('notice', 1),
#  ('leaning', 1),
#  ('convention', 1),
#  ('small', 1),
#  ('downloaded', 1),
#  ('commandeered', 1),
#  ('setting', 1),
#  ('relinquish', 1),
#  ('ready', 1),
#  ('realized', 1),
#  ('shitty', 1),
#  ('several', 1),
#  ('cited', 1),
#  ('opposite', 1),
#  ('crowdsourcing', 1),
#  ('proprietary', 1),
#  ('bahahahaha', 1),
#  ('least', 1),
#  ('past', 1),
#  ('supposed', 1),
#  ('downstairs', 1),
#  ('cult', 1),
#  ('vega', 1),
#  ('warmer', 1),
#  ('alive', 1),
#  ('indie', 1),
#  ('development', 1),
#  ('kind', 1),
#  ('downer', 1),
#  ('abandoned', 1),
#  ('reality', 1),
#  ('communication', 1),
#  ('happened', 1),
#  ('utter', 1),
#  ('letter', 1),
#  ('wrap', 1),
#  ('cc', 1),
#  ('apparent', 1),
#  ('removable', 1),
#  ('geo', 1),
#  ('foursquare', 1),
#  ('gowalla', 1),
#  ('bruise', 1),
#  ('regarded', 1),
#  ('corporate', 1),
#  ('transparency', 1),
#  ('evolve', 1),
#  ('impossible', 1),
#  ('mb', 1),
#  ('sooo', 1),
#  ('sxxpress', 1),
#  ('exposing', 1),
#  ('horrendous', 1),
#  ('skip', 1),
#  ('barely', 1),
#  ('shrink', 1),
#  ('pollak', 1),
#  ('trouble', 1),
#  ('duh', 1),
#  ('turning', 1),
#  ('kicking', 1),
#  ('talking', 1),
#  ('neither', 1),
#  ('grrr', 1),
#  ('partial', 1),
#  ('fine', 1),
#  ('deciding', 1),
#  ('ride', 1),
#  ('hell', 1),
#  ('dinner', 1),
#  ('party', 1),
#  ('worse', 1),
#  ('face', 1),
#  ('admits', 1),
#  ('wordpress', 1),
#  ('honesty', 1),
#  ('faulty', 1),
#  ('quicker', 1),
#  ('behave', 1),
#  ('simple', 1),
#  ('often', 1),
#  ('season', 1),
#  ('guild', 1),
#  ('abt', 1),
#  ('hijack', 1),
#  ('top', 1),
#  ('math', 1),
#  ('ahead', 1),
#  ('miss', 1),
#  ('impression', 1),
#  ('lemon', 1),
#  ('backlight', 1),
#  ('bleed', 1),
#  ('thru', 1),
#  ('bottom', 1),
#  ('stylish', 1),
#  ('crushing', 1),
#  ('endorsement', 1),
#  ('rip', 1),
#  ('june', 1),
#  ('survived', 1),
#  ('severe', 1),
#  ('drop', 1),
#  ('evade', 1),
#  ('le', 1),
#  ('total', 1),
#  ('yeah', 1),
#  ('ken', 1),
#  ('calhoun', 1),
#  ('bringing', 1),
#  ('itunes', 1),
#  ('ie', 1),
#  ('ubuntu', 1),
#  ('desktop', 1),
#  ('dl', 1),
#  ('outdid', 1),
#  ('totalitarian', 1),
#  ('action', 1),
#  ('worldwide', 1),
#  ('decide', 1),
#  ('related', 1),
#  ('verizon', 1),
#  ('bandwidth', 1),
#  ('tweeted', 1),
#  ('dawdled', 1),
#  ('ui', 1),
#  ('ûïbuttons', 1),
#  ('skepticism', 1),
#  ('ûï', 1),
#  ('smart', 1),
#  ('farm', 1),
#  ('xoom', 1),
#  ('emulates', 1),
#  ('mouse', 1),
#  ('click', 1),
#  ('input', 1),
#  ('techie', 1),
#  ('moderator', 1),
#  ('europe', 1),
#  ('move', 1),
#  ('browser', 1),
#  ('replicate', 1),
#  ('press', 1),
#  ('thinking', 1),
#  ('actually', 1),
#  ('alone', 1),
#  ('trip', 1),
#  ('playing', 1),
#  ('windows7', 1),
#  ('animation', 1),
#  ('instagram', 1),
#  ('moment', 1),
#  ('mister', 1),
#  ('evo', 1),
#  ('care', 1),
#  ('awkward', 1),
#  ('louis', 1),
#  ('vuitton', 1),
#  ('amble', 1),
#  ('row', 1),
#  ('writing', 1),
#  ('monopoly', 1),
#  ('publisher', 1),
#  ('enhancement', 1),
#  ('th', 1),
#  ('david', 1),
#  ('foster', 1),
#  ('wallace', 1),
#  ('footnote', 1),
#  ...]

# %%
tokens_neg_Ap =  df_neg_Apple['text_tokenized_lemmatized']
tokens_neg_Ap_flat = [item for sublist in tokens_neg_Ap  for item in sublist]

# %%
#generating word cloud
cloud_pos_w_company = generate_wordcloud(tokens_neg_Ap_flat, collocations=True)

# %% [markdown]
# We see names like austin, people, new, think as most common words. They do not show any emotion, thus we can add them to the stop list and check for the common words again.

# %%
stop_words += ['austin', 'people', 'new', 'think', 'line', 'one', 'look']

# %%
# Apply the function to the tokenized text column
df_neg_Apple['text_tokenized_lemmatized'] = df_neg_Apple['text_tokenized_lemmatized'].apply(remove_stop_words)
# Out:
# <ipython-input-512-1e4268896d12>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_neg_Apple['text_tokenized_lemmatized'] = df_neg_Apple['text_tokenized_lemmatized'].apply(remove_stop_words)

# %%
tokens_neg_Ap =  df_neg_Apple['text_tokenized_lemmatized']
tokens_neg_Ap_flat = [item for sublist in tokens_neg_Ap  for item in sublist]

# %%
#generating word cloud
cloud_pos_w_company = generate_wordcloud(tokens_neg_Ap_flat, collocations=True)

# %% [markdown]
# Now we can identify negative words directed at the apple company; words like, nothing good, design headach, fascist company, fade fast, classies fascist, stupid, really, gave money etc.

# %%
# Looking at the top 10 most popular words, @user_accounts and hashtags
# 25 Most popular words

from nltk import FreqDist
tokens_count = [token for tokens in df_neg_Google['text_tokenized_lemmatized'] for token in tokens]
freq = FreqDist(tokens_count)
freq.most_common(10)
# Out:
# [('google', 137),
#  ('circle', 29),
#  ('social', 26),
#  ('new', 21),
#  ('launch', 19),
#  ('network', 17),
#  ('today', 16),
#  ('product', 13),
#  ('android', 13),
#  ('major', 12)]

# %%
# Apply the function to the tokenized text column
df_neg_Google['text_tokenized_lemmatized'] = df_neg_Google['text_tokenized_lemmatized'].apply(remove_stop_words)
# Out:
# <ipython-input-516-5881e344f79e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_neg_Google['text_tokenized_lemmatized'] = df_neg_Google['text_tokenized_lemmatized'].apply(remove_stop_words)

# %%
# Looking at the top 10 most popular words, @user_accounts and hashtags
# 25 Most popular words

from nltk import FreqDist
tokens_count = [token for tokens in df_neg_Google['text_tokenized_lemmatized'] for token in tokens]
freq = FreqDist(tokens_count)
freq.most_common(10)
# Out:
# [('circle', 29),
#  ('social', 26),
#  ('launch', 19),
#  ('network', 17),
#  ('today', 16),
#  ('product', 13),
#  ('major', 12),
#  ('need', 12),
#  ('called', 11),
#  ('mayer', 10)]

# %%
tokens_neg_Go =  df_neg_Google['text_tokenized_lemmatized']
tokens_neg_Go_flat = [item for sublist in tokens_neg_Go  for item in sublist]

# %%
#generating word cloud
generate_wordcloud(tokens_neg_Go_flat, collocations=True)

# %%
from nltk import ngrams
# Generate bigrams
bigrams = list(ngrams(tokens_neg_Go_flat, 2))
bigrams
# Out:
# [('false', 'alarm'),
#  ('alarm', 'circle'),
#  ('circle', 'coming'),
#  ('coming', 'ûòand'),
#  ('ûòand', 'probably'),
#  ('probably', 'ever'),
#  ('ever', 'v'),
#  ('v', 'bing'),
#  ('bing', 'bing'),
#  ('bing', 'shot'),
#  ('shot', 'success'),
#  ('success', 'structured'),
#  ('structured', 'search'),
#  ('search', 'potentially'),
#  ('potentially', 'higher'),
#  ('higher', 'margin'),
#  ('margin', 'cpa'),
#  ('cpa', 'model'),
#  ('model', 'v'),
#  ('v', 'length'),
#  ('length', 'penalty'),
#  ('penalty', 'based'),
#  ('based', 'severity'),
#  ('severity', 'breach'),
#  ('breach', 'webmaster'),
#  ('webmaster', 'guideline'),
#  ('guideline', 'white'),
#  ('white', 'text'),
#  ('text', 'white'),
#  ('white', 'bgr'),
#  ('bgr', 'might'),
#  ('might', 'get'),
#  ('get', 'day'),
#  ('day', 'pen'),
#  ('pen', 'launch'),
#  ('launch', 'major'),
#  ('major', 'social'),
#  ('social', 'network'),
#  ('network', 'called'),
#  ('called', 'circle'),
#  ('circle', 'possibly'),
#  ('possibly', 'today'),
#  ('today', 'never'),
#  ('never', 'beat'),
#  ('beat', 'myspace'),
#  ('myspace', 'interested'),
#  ('interested', 'location'),
#  ('location', 'based'),
#  ('based', 'tech'),
#  ('tech', 'indoor'),
#  ('indoor', 'venue'),
#  ('venue', 'business'),
#  ('business', 'convention'),
#  ('convention', 'center'),
#  ('center', 'etc'),
#  ('etc', 'tech'),
#  ('tech', 'need'),
#  ('need', 'improve'),
#  ('improve', 'first'),
#  ('first', 'location'),
#  ('location', 'pixieengine'),
#  ('pixieengine', 'say'),
#  ('say', 'future'),
#  ('future', 'location'),
#  ('location', 'location'),
#  ('location', 'location'),
#  ('location', 'launch'),
#  ('launch', 'major'),
#  ('major', 'social'),
#  ('social', 'network'),
#  ('network', 'called'),
#  ('called', 'circle'),
#  ('circle', 'updated'),
#  ('updated', 'launched'),
#  ('launched', 'soon'),
#  ('soon', 'care'),
#  ('care', 'launch'),
#  ('launch', 'product'),
#  ('product', 'wait'),
#  ('wait', 'launch'),
#  ('launch', 'product'),
#  ('product', 'exists'),
#  ('exists', 'wait'),
#  ('wait', 'product'),
#  ('product', 'exist'),
#  ('exist', 'compiling'),
#  ('compiling', 'list'),
#  ('list', 'doc'),
#  ('doc', 'taking'),
#  ('taking', 'lot'),
#  ('lot', 'longer'),
#  ('longer', 'thought'),
#  ('thought', 'many'),
#  ('many', 'party'),
#  ('party', 'many'),
#  ('many', 'good'),
#  ('good', 'musician'),
#  ('musician', 'hm'),
#  ('hm', 'need'),
#  ('need', 'another'),
#  ('another', 'launch'),
#  ('launch', 'major'),
#  ('major', 'social'),
#  ('social', 'network'),
#  ('network', 'called'),
#  ('called', 'circle'),
#  ('circle', 'possibly'),
#  ('possibly', 'today'),
#  ('today', 'launching'),
#  ('launching', 'anything'),
#  ('anything', 'partying'),
#  ('partying', 'problem'),
#  ('problem', 'living'),
#  ('living', 'story'),
#  ('story', 'process'),
#  ('process', 'creating'),
#  ('creating', 'content'),
#  ('content', 'change'),
#  ('change', 'interface'),
#  ('interface', 'law'),
#  ('law', 'average'),
#  ('average', 'better'),
#  ('better', 'buzz'),
#  ('buzz', 'circle'),
#  ('circle', '______'),
#  ('______', 'social'),
#  ('social', 'site'),
#  ('site', 'like'),
#  ('like', 'delicious'),
#  ('delicious', 'often'),
#  ('often', 'better'),
#  ('better', 'result'),
#  ('result', 'bing'),
#  ('bing', 'get'),
#  ('get', 'see'),
#  ('see', 'fail'),
#  ('fail', 'social'),
#  ('social', 'another'),
#  ('another', 'day'),
#  ('day', 'okay'),
#  ('okay', 'circle'),
#  ('circle', 'debuting'),
#  ('debuting', 'today'),
#  ('today', 'trajan'),
#  ('trajan', 'destroyed'),
#  ('destroyed', 'lt'),
#  ('lt', 'title'),
#  ('title', 'gt'),
#  ('gt', 'tag'),
#  ('tag', 'website'),
#  ('website', 'seo'),
#  ('seo', 'open'),
#  ('open', 'graph'),
#  ('graph', 'protocol'),
#  ('protocol', 'added'),
#  ('added', 'clean'),
#  ('clean', 'title'),
#  ('title', 'tag'),
#  ('tag', 'instead'),
#  ('instead', 'dense'),
#  ('dense', 'una'),
#  ('una', 'vuelta'),
#  ('vuelta', 'por'),
#  ('por', 'para'),
#  ('para', 'ver'),
#  ('ver', 'la'),
#  ('la', 'gran'),
#  ('gran', 'diferencia'),
#  ('diferencia', 'revolution'),
#  ('revolution', 'clumsily'),
#  ('clumsily', 'translated'),
#  ('translated', 'thought'),
#  ('thought', 'social'),
#  ('social', 'get'),
#  ('get', 'overblown'),
#  ('overblown', 'may'),
#  ('may', 'announcing'),
#  ('announcing', 'circle'),
#  ('circle', 'today'),
#  ('today', 'true'),
#  ('true', 'lost'),
#  ('lost', 'way'),
#  ('way', 'caring'),
#  ('caring', 'much'),
#  ('much', 'business'),
#  ('business', 'v'),
#  ('v', 'user'),
#  ('user', 'worked'),
#  ('worked', 'year'),
#  ('year', 'seen'),
#  ('seen', 'lot'),
#  ('lot', 'evil'),
#  ('evil', 'smackdown'),
#  ('smackdown', 'bloody'),
#  ('bloody', 'banality'),
#  ('banality', 'brain'),
#  ('brain', 'apology'),
#  ('apology', 'randy'),
#  ('randy', 'ad'),
#  ('ad', 'popping'),
#  ('popping', 'search'),
#  ('search', 'result'),
#  ('result', 'algorithm'),
#  ('algorithm', 'skewed'),
#  ('skewed', 'weekend'),
#  ('weekend', 'randy'),
#  ('randy', 'query'),
#  ('query', 'attendee'),
#  ('attendee', 'meetups'),
#  ('meetups', 'work'),
#  ('work', 'well'),
#  ('well', 'least'),
#  ('least', 'p'),
#  ('p', 'meetup'),
#  ('meetup', 'another'),
#  ('another', 'social'),
#  ('social', 'failure'),
#  ('failure', 'guy'),
#  ('guy', 'asked'),
#  ('asked', 'mayer'),
#  ('mayer', 'take'),
#  ('take', 'year'),
#  ('year', 'remove'),
#  ('remove', 'deadly'),
#  ('deadly', 'route'),
#  ('route', 'map'),
#  ('map', 'death'),
#  ('death', 'valley'),
#  ('valley', 'marissa'),
#  ('marissa', 'mayer'),
#  ('mayer', 'map'),
#  ('map', 'better'),
#  ('better', 'customer'),
#  ('customer', 'service'),
#  ('service', 'quicker'),
#  ('quicker', 'response'),
#  ('response', 'walk'),
#  ('walk', 'lady'),
#  ('lady', 'bird'),
#  ('bird', 'lake'),
#  ('lake', 'lovely'),
#  ('lovely', 'map'),
#  ('map', 'travel'),
#  ('travel', 'time'),
#  ('time', 'trusted'),
#  ('trusted', 'trying'),
#  ('trying', 'convince'),
#  ('convince', 'watch'),
#  ('watch', 'launch'),
#  ('launch', 'social'),
#  ('social', 'network'),
#  ('network', 'know'),
#  ('know', 'going'),
#  ('going', 'comedy'),
#  ('comedy', 'data'),
#  ('data', 'crunch'),
#  ('crunch', 'crippling'),
#  ('crippling', 'voice'),
#  ('voice', 'back'),
#  ('back', 'regular'),
#  ('regular', 'texting'),
#  ('texting', 'go'),
#  ('go', 'bing'),
#  ('bing', 'meet'),
#  ('meet', 'lover'),
#  ('lover', 'tiff'),
#  ('tiff', 'last'),
#  ('last', 'month'),
#  ('month', 'seems'),
#  ('seems', 'disappointingly'),
#  ('disappointingly', 'friendly'),
#  ('friendly', 'bing'),
#  ('bing', 'page'),
#  ('page', 'rank'),
#  ('rank', 'panel'),
#  ('panel', 'ridiculously'),
#  ('ridiculously', 'crowded'),
#  ('crowded', 'al'),
#  ('al', 'franken'),
#  ('franken', 'justin'),
#  ('justin', 'timberlake'),
#  ('timberlake', 'circle'),
#  ('circle', 'game'),
#  ('game', 'try'),
#  ('try', 'launch'),
#  ('launch', 'social'),
#  ('social', 'network'),
#  ('network', 'called'),
#  ('called', 'circle'),
#  ('circle', 'future'),
#  ('future', 'network'),
#  ('network', 'data'),
#  ('data', 'may'),
#  ('may', 'win'),
#  ('win', 'long'),
#  ('long', 'term'),
#  ('term', 'heck'),
#  ('heck', 'map'),
#  ('map', 'use'),
#  ('use', 'browser'),
#  ('browser', 'geo'),
#  ('geo', 'location'),
#  ('location', 'missing'),
#  ('missing', 'somehow'),
#  ('somehow', 'using'),
#  ('using', 'chrome'),
#  ('chrome', 'prefers'),
#  ('prefers', 'launch'),
#  ('launch', 'hyped'),
#  ('hyped', 'social'),
#  ('social', 'feature'),
#  ('feature', 'meh'),
#  ('meh', 'bang'),
#  ('bang', 'via'),
#  ('via', 'tc'),
#  ('tc', 'seems'),
#  ('seems', 'sabotaged'),
#  ('sabotaged', 'youtube'),
#  ('youtube', 'account'),
#  ('account', 'wtf'),
#  ('wtf', 'trying'),
#  ('trying', 'entire'),
#  ('entire', 'online'),
#  ('online', 'ecosystem'),
#  ('ecosystem', 'bad'),
#  ('bad', 'form'),
#  ('form', 'ha'),
#  ('ha', 'guy'),
#  ('guy', 'talk'),
#  ('talk', 'explaining'),
#  ('explaining', 'made'),
#  ('made', 'realistic'),
#  ('realistic', 'twitter'),
#  ('twitter', 'bot'),
#  ('bot', 'experiment'),
#  ('experiment', 'gee'),
#  ('gee', 'thanks'),
#  ('thanks', 'gamechanger'),
#  ('gamechanger', 'like'),
#  ('like', 'wave'),
#  ('wave', 'buzz'),
#  ('buzz', 'doubt'),
#  ('doubt', 'launch'),
#  ('launch', 'major'),
#  ('major', 'social'),
#  ('social', 'network'),
#  ('network', 'called'),
#  ('called', 'circle'),
#  ('circle', 'presentation'),
#  ('presentation', 'mayer'),
#  ('mayer', 'sale'),
#  ('sale', 'pitch'),
#  ('pitch', 'awesome'),
#  ('awesome', 'hear'),
#  ('hear', 'marissa'),
#  ('marissa', 'mayer'),
#  ('mayer', 'acknowledge'),
#  ('acknowledge', 'map'),
#  ('map', 'need'),
#  ('need', 'increase'),
#  ('increase', 'support'),
#  ('support', 'product'),
#  ('product', 'incorrect'),
#  ('incorrect', 'route'),
#  ('route', 'many'),
#  ('many', 'product'),
#  ('product', 'need'),
#  ('need', 'condense'),
#  ('condense', 'fyi'),
#  ('fyi', 'nine'),
#  ('nine', 'mobile'),
#  ('mobile', 'product'),
#  ('product', 'technical'),
#  ('technical', 'solution'),
#  ('solution', 'great'),
#  ('great', 'community'),
#  ('community', 'human'),
#  ('human', 'solution'),
#  ('solution', 'launch'),
#  ('launch', 'major'),
#  ('major', 'social'),
#  ('social', 'network'),
#  ('network', 'really'),
#  ('really', 'dont'),
#  ('dont', 'need'),
#  ('need', 'another'),
#  ('another', 'social'),
#  ('social', 'network'),
#  ('network', 'calendar'),
#  ('calendar', 'getting'),
#  ('getting', 'little'),
#  ('little', 'control'),
#  ('control', 'circle'),
#  ('circle', 'lame'),
#  ('lame', 'lt'),
#  ('lt', 'lost'),
#  ('lost', 'way'),
#  ('way', 'caring'),
#  ('caring', 'much'),
#  ('much', 'business'),
#  ('business', 'instead'),
#  ('instead', 'user'),
#  ('user', 'tim'),
#  ('tim', 'reilly'),
#  ('reilly', 'us'),
#  ('us', 'tv'),
#  ('tv', 'room'),
#  ('room', 'nobody'),
#  ('nobody', 'raise'),
#  ('raise', 'hand'),
#  ('hand', 'packed'),
#  ('packed', 'room'),
#  ('room', 'session'),
#  ('session', 'lunch'),
#  ('lunch', 'view'),
#  ('view', 'html5'),
#  ('html5', 'dev'),
#  ('dev', 'trench'),
#  ('trench', 'painful'),
#  ('painful', 'io'),
#  ('io', 'sleek'),
#  ('sleek', 'open'),
#  ('open', 'graph'),
#  ('graph', 'repair'),
#  ('repair', 'damage'),
#  ('damage', 'title'),
#  ('title', 'tag'),
#  ('tag', 'beware'),
#  ('beware', 'schedule'),
#  ('schedule', 'completely'),
#  ('completely', 'innacurate'),
#  ('innacurate', 'walked'),
#  ('walked', 'hyatt'),
#  ('hyatt', 'reason'),
#  ('reason', 'data'),
#  ('data', 'oil'),
#  ('oil', 'company'),
#  ('company', 'like'),
#  ('like', 'facebook'),
#  ('facebook', 'monopoly'),
#  ('monopoly', 'term'),
#  ('term', 'service'),
#  ('service', 'wary'),
#  ('wary', 'going'),
#  ('going', 'let'),
#  ('let', 'meet'),
#  ('meet', 'use'),
#  ('use', 'yet'),
#  ('yet', 'phone'),
#  ('phone', 'show'),
#  ('show', 'work'),
#  ('work', 'guessing'),
#  ('guessing', 'time'),
#  ('time', 'make'),
#  ('make', 'feel'),
#  ('feel', 'better'),
#  ('better', 'wannabe'),
#  ('wannabe', 'fanbois'),
#  ('fanbois', 'acting'),
#  ('acting', 'like'),
#  ('like', 'giggling'),
#  ('giggling', 'schoolgirl'),
#  ('schoolgirl', 'front'),
#  ('front', 'marissa'),
#  ('marissa', 'mayer'),
#  ('mayer', 'day'),
#  ('day', 'hey'),
#  ('hey', 'got'),
#  ('got', 'invited'),
#  ('invited', 'group'),
#  ('group', 'keep'),
#  ('keep', 'crashing'),
#  ('crashing', 'try'),
#  ('try', 'join'),
#  ('join', 'wtf'),
#  ('wtf', 'hey'),
#  ('hey', 'download'),
#  ('download', 'market'),
#  ('market', 'head'),
#  ('head', 'cant'),
#  ('cant', 'wait'),
#  ('wait', 'give'),
#  ('give', 'samsung'),
#  ('samsung', 'demo'),
#  ('demo', 'horrible'),
#  ('horrible', 'terrible'),
#  ('terrible', 'nexus'),
#  ('nexus', 'phone'),
#  ('phone', 'next'),
#  ('next', 'step'),
#  ('step', 'becoming'),
#  ('becoming', 'skynet'),
#  ('skynet', 'take'),
#  ('take', 'mantra'),
#  ('mantra', 'dont'),
#  ('dont', 'evil'),
#  ('evil', 'heart'),
#  ('heart', 'yet'),
#  ('yet', 'pride'),
#  ('pride', 'product'),
#  ('product', 'make'),
#  ('make', 'guilty'),
#  ('guilty', 'deadly'),
#  ('deadly', 'sin'),
#  ('sin', 'superbia'),
#  ('superbia', 'launched'),
#  ('launched', 'next'),
#  ('next', 'social'),
#  ('social', 'medium'),
#  ('medium', 'flop'),
#  ('flop', 'yet'),
#  ('yet', 'dear'),
#  ('dear', 'photobooth'),
#  ('photobooth', 'suck'),
#  ('suck', 'eat'),
#  ('eat', 'hilton'),
#  ('hilton', 'launch'),
#  ('launch', 'facebook'),
#  ('facebook', 'competitor'),
#  ('competitor', 'circle'),
#  ('circle', 'today'),
#  ('today', 'thought'),
#  ('thought', 'creeper'),
#  ('creeper', 'half'),
#  ('half', 'friend'),
#  ('friend', 'world'),
#  ('world', 'disappointed'),
#  ('disappointed', 'suck'),
#  ('suck', 'preview'),
#  ('preview', 'major'),
#  ('major', 'social'),
#  ('social', 'service'),
#  ('service', 'circle'),
#  ('circle', 'today'),
#  ('today', 'feel'),
#  ('feel', 'silly'),
#  ('silly', 'cannot'),
#  ('cannot', 'figure'),
#  ('figure', 'update'),
#  ('update', 'mobile'),
#  ('mobile', 'seem'),
#  ('seem', 'option'),
#  ('option', 'bottom'),
#  ('bottom', 'left'),
#  ('left', 'button'),
#  ('button', 'really'),
#  ('really', 'hoping'),
#  ('hoping', 'would'),
#  ('would', 'bring'),
#  ('bring', 'version'),
#  ('version', 'oh'),
#  ('oh', 'well'),
#  ('well', 'maybe'),
#  ('maybe', 'someday'),
#  ('someday', 'long'),
#  ('long', 'time'),
#  ('time', 'overload'),
#  ('overload', 'info'),
#  ('info', 'delivered'),
#  ('delivered', 'kill'),
#  ('kill', 'discovery'),
#  ('discovery', 'say'),
#  ('say', 'ppl'),
#  ('ppl', 'lose'),
#  ('lose', 'curiosity'),
#  ('curiosity', 'wonder'),
#  ('wonder', 'need'),
#  ('need', 'serendipity'),
#  ('serendipity', 'failure'),
#  ('failure', 'buzz'),
#  ('buzz', 'latitude'),
#  ('latitude', 'circle'),
#  ('circle', 'seriously'),
#  ('seriously', 'need'),
#  ('need', 'concentrate'),
#  ('concentrate', 'search'),
#  ('search', 'finally'),
#  ('finally', 'get'),
#  ('get', 'everyone'),
#  ('everyone', 'buy'),
#  ('buy', 'facebook'),
#  ('facebook', 'introduces'),
#  ('introduces', 'circle'),
#  ('circle', 'fair'),
#  ('fair', 'stop'),
#  ('stop', 'innovation'),
#  ('innovation', 'finally'),
#  ('finally', 'get'),
#  ('get', 'everyone'),
#  ('everyone', 'buy'),
#  ('buy', 'facebook'),
#  ('facebook', 'introduces'),
#  ('introduces', 'circle'),
#  ('circle', 'fair'),
#  ('fair', 'stop'),
#  ('stop', 'innovation'),
#  ('innovation', 'nope'),
#  ('nope', 'seems'),
#  ('seems', 'circle'),
#  ('circle', 'launch'),
#  ('launch', 'today'),
#  ('today', 'ahhh'),
#  ('ahhh', 'darn'),
#  ('darn', 'according'),
#  ('according', 'confirmed'),
#  ('confirmed', 'launching'),
#  ('launching', 'woman'),
#  ('woman', 'great'),
#  ('great', 'fessing'),
#  ('fessing', 'issue'),
#  ('issue', 'admitting'),
#  ('admitting', 'could'),
#  ('could', 'better'),
#  ('better', 'grrr'),
#  ('grrr', 'plancast'),
#  ('plancast', 'stuff'),
#  ('stuff', 'exported'),
#  ('exported', 'calendar'),
#  ('calendar', 'san'),
#  ('san', 'diego'),
#  ('diego', 'pacific'),
#  ('pacific', 'time'),
#  ('time', 'shift'),
#  ('shift', 'central'),
#  ('central', 'tme'),
#  ('tme', 'anyone'),
#  ('anyone', 'address'),
#  ('address', 'yeasayer'),
#  ('yeasayer', 'concert'),
#  ('concert', 'tonight'),
#  ('tonight', 'map'),
#  ('map', 'failing'),
#  ('failing', 'interesting'),
#  ('interesting', 'technical'),
#  ('technical', 'solution'),
#  ('solution', 'great'),
#  ('great', 'community'),
#  ('community', 'human'),
#  ('human', 'solution'),
#  ('solution', 'nice'),
#  ('nice', 'song'),
#  ('song', 'ûªt'),
#  ('ûªt', 'hack'),
#  ('hack', 'write'),
#  ('write', 'rail'),
#  ('rail', 'deliver'),
#  ('deliver', 'sell'),
#  ('sell', 'work'),
#  ('work', 'da'),
#  ('da', 'verpixelungsrecht'),
#  ('verpixelungsrecht', 'ûóthe'),
#  ('ûóthe', 'right'),
#  ('right', 'house'),
#  ('house', 'pixelated'),
#  ('pixelated', 'street'),
#  ('street', 'view'),
#  ('view', 'ûó'),
#  ('ûó', 'theft'),
#  ('theft', 'public'),
#  ('public', 'mayer'),
#  ('mayer', 'also'),
#  ('also', 'admits'),
#  ('admits', 'need'),
#  ('need', 'step'),
#  ('step', 'customer'),
#  ('customer', 'support'),
#  ('support', 'map'),
#  ('map', 'expensive'),
#  ('expensive', 'mobile'),
#  ('mobile', 'data'),
#  ('data', 'plan'),
#  ('plan', 'killing'),
#  ('killing', 'flavor'),
#  ('flavor', 'contextual'),
#  ('contextual', 'discovery'),
#  ('discovery', 'abroad'),
#  ('abroad', 'excited'),
#  ('excited', 'meet'),
#  ('meet', 'show'),
#  ('show', 'sprint'),
#  ('sprint', 'galaxy'),
#  ('galaxy', 'still'),
#  ('still', 'running'),
#  ('running', 'product'),
#  ('product', 'showcase'),
#  ('showcase', 'never'),
#  ('never', 'feel'),
#  ('feel', 'cool'),
#  ('cool', 'price'),
#  ('price', 'tag'),
#  ('tag', 'brand'),
#  ('brand', 'equity'),
#  ('equity', 'wow'),
#  ('wow', 'factor'),
#  ('factor', 'attached'),
#  ('attached', 'marissa'),
#  ('marissa', 'mayer'),
#  ('mayer', 'lost'),
#  ('lost', 'way'),
#  ('way', 'caring'),
#  ('caring', 'much'),
#  ('much', 'business'),
#  ('business', 'v'),
#  ('v', 'user'),
#  ('user', 'false'),
#  ('false', 'alarm'),
#  ('alarm', 'circle'),
#  ('circle', 'coming'),
#  ('coming', 'ûòand'),
#  ('ûòand', 'probably'),
#  ('probably', 'ever'),
#  ('ever', 'technical'),
#  ('technical', 'solution'),
#  ('solution', 'great'),
#  ('great', 'community'),
#  ('community', 'human'),
#  ('human', 'solution'),
#  ('solution', 'reason'),
#  ('reason', 'social'),
#  ('social', 'technical'),
#  ('technical', 'trajan'),
#  ('trajan', 'destroyed'),
#  ('destroyed', 'lt'),
#  ('lt', 'title'),
#  ('title', 'gt'),
#  ('gt', 'tag'),
#  ('tag', 'website'),
#  ('website', 'seo'),
#  ('seo', 'open'),
#  ('open', 'graph'),
#  ('graph', 'protocol'),
#  ('protocol', 'added'),
#  ('added', 'clean'),
#  ('clean', 'title'),
#  ('title', 'tag'),
#  ('tag', 'instead'),
#  ('instead', 'bing'),
#  ('bing', 'smackdown'),
#  ('smackdown', 'bloody'),
#  ('bloody', 'banality'),
#  ('banality', 'guardian'),
#  ('guardian', 'via'),
#  ('via', 'waze'),
#  ('waze', 'duking'),
#  ('duking', 'personalized'),
#  ('personalized', 'mapping'),
#  ('mapping', 'experience'),
#  ('experience', 'friendly'),
#  ('friendly', 'panel'),
#  ('panel', 'crashing'),
#  ('crashing', 'diabetes'),
#  ('diabetes', 'plate'),
#  ('plate', 'thanks'),
#  ('thanks', 'already'),
#  ('already', 'covered'),
#  ('covered', 'suck'),
#  ('suck', 'preview'),
#  ('preview', 'major'),
#  ('major', 'social'),
#  ('social', 'service'),
#  ('service', 'circle'),
#  ('circle', 'today'),
#  ('today', 'apparently'),
#  ('apparently', 'ad'),
#  ('ad', 'preference'),
#  ('preference', 'see'),
#  ('see', 'like'),
#  ('like', 'brought'),
#  ('brought', 'map'),
#  ('map', 'rerouted'),
#  ('rerouted', 'image'),
#  ('image', 'jcpenney'),
#  ('jcpenney', 'image'),
#  ('image', 'macys'),
#  ('macys', 'trashy'),
#  ('trashy', 'restraunts'),
#  ('restraunts', 'comment'),
#  ('comment', 'deliciously'),
#  ('deliciously', 'ironic'),
#  ('ironic', 'privacy'),
#  ('privacy', 'party'),
#  ('party', 'made'),
#  ('made', 'whole'),
#  ('whole', 'banking'),
#  ('banking', 'cartel'),
#  ('cartel', 'military'),
#  ('military', 'scientific'),
#  ('scientific', 'dictatorship'),
#  ('dictatorship', 'takeover'),
#  ('takeover', 'cab'),
#  ('cab', 'rant'),
#  ('rant', 'diller'),
#  ('diller', 'tv'),
#  ('tv', 'first'),
#  ('first', 'product'),
#  ('product', 'good'),
#  ('good', 'consumer'),
#  ('consumer', 'product'),
#  ('product', 'basically'),
#  ('basically', 'false'),
#  ('false', 'alarm'),
#  ('alarm', 'circle'),
#  ('circle', 'coming'),
#  ('coming', 'probably'),
#  ('probably', 'ever'),
#  ('ever', 'much'),
#  ('much', 'report'),
#  ('report', 'would'),
#  ('would', 'unveil'),
#  ('unveil', 'fodder'),
#  ('fodder', 'panel'),
#  ('panel', 'right'),
#  ('right', 'forget'),
#  ('forget', 'gain'),
#  ('gain', 'traction'),
#  ('traction', 'europe'),
#  ('europe', 'causing'),
#  ('causing', 'issue'),
#  ('issue', 'circle'),
#  ('circle', 'toast'),
#  ('toast', 'convince'),
#  ('convince', 'facebook'),
#  ('facebook', 'user'),
#  ('user', 'start'),
#  ('start', 'account'),
#  ('account', 'interface'),
#  ('interface', 'fb'),
#  ('fb', 'hotpot'),
#  ('hotpot', 'rate'),
#  ('rate', 'restaurant'),
#  ('restaurant', 'get'),
#  ('get', 'personalized'),
#  ('personalized', 'recos'),
#  ('recos', 'eat'),
#  ('eat', 'um'),
#  ('um', 'foursquare'),
#  ('foursquare', 'yelp'),
#  ('yelp', 'etc'),
#  ('etc', 'covered'),
#  ('covered', 'already'),
#  ('already', 'latina'),
#  ('latina', 'see'),
#  ('see', 'find'),
#  ('find', 'porn'),
#  ('porn', 'first'),
#  ('first', 'impression'),
#  ('impression', 'get'),
#  ('get', 'u'),
#  ('u', 'presentation'),
#  ('presentation', 'mayer'),
#  ('mayer', 'sale'),
#  ('sale', 'pitch'),
#  ('pitch', 'launch'),
#  ('launch', 'major'),
#  ('major', 'social'),
#  ('social', 'network'),
#  ('network', 'called'),
#  ('called', 'circle'),
#  ('circle', 'possibly'),
#  ('possibly', 'today'),
#  ('today', 'rww'),
#  ('rww', 'f6bcet'),
#  ('f6bcet', 'goody'),
#  ('goody', 'overload'),
#  ('overload', 'v'),
#  ('v', 'bing'),
#  ('bing', 'bing'),
#  ('bing', 'shot'),
#  ('shot', 'success'),
#  ('success', 'structured'),
#  ('structured', 'search'),
#  ('search', 'potentially'),
#  ('potentially', 'higher'),
#  ('higher', 'margin'),
#  ('margin', 'cpa'),
#  ('cpa', 'model'),
#  ('model', 'v'),
#  ('v', 'incapable'),
#  ('incapable', 'disruptive'),
#  ('disruptive', 'innovation'),
#  ('innovation', 'acquired'),
#  ('acquired', 'startup'),
#  ('startup', 'last'),
#  ('last', 'year'),
#  ('year', 'hm'),
#  ('hm', 'need'),
#  ('need', 'another'),
#  ('another', 'launch'),
#  ('launch', 'major'),
#  ('major', 'social'),
#  ('social', 'network'),
#  ('network', 'called'),
#  ('called', 'circle'),
#  ('circle', 'possibly'),
#  ('possibly', 'today'),
#  ('today', 'cant'),
#  ('cant', 'wait'),
#  ('wait', 'give'),
#  ('give', 'samsung'),
#  ('samsung', 'demo'),
#  ('demo', 'horrible'),
#  ('horrible', 'terrible'),
#  ('terrible', 'nexus'),
#  ('nexus', 'phone'),
#  ('phone', 'lost'),
#  ('lost', 'way'),
#  ('way', 'caring'),
#  ('caring', 'much'),
#  ('much', 'business'),
#  ('business', 'instead'),
#  ('instead', 'user'),
#  ('user', 'tim'),
#  ('tim', 'reilly'),
#  ('reilly', 'room'),
#  ('room', 'full'),
#  ('full', 'geek'),
#  ('geek', 'talking'),
#  ('talking', 'tv'),
#  ('tv', 'asked'),
#  ('asked', 'us'),
#  ('us', 'tv'),
#  ('tv', 'raised'),
#  ('raised', 'hand'),
#  ('hand', 'ironic'),
#  ('ironic', 'googled'),
#  ('googled', 'direction'),
#  ('direction', 'party'),
#  ('party', 'ended'),
#  ('ended', 'walked'),
#  ('walked', 'block'),
#  ('block', 'wrong'),
#  ('wrong', 'direction'),
#  ('direction', 'time'),
#  ('time', 'bed'),
#  ('bed', 'launch'),
#  ('launch', 'major'),
#  ('major', 'social'),
#  ('social', 'network'),
#  ('network', 'called'),
#  ('called', 'possibly'),
#  ('possibly', 'today'),
#  ('today', 'gt'),
#  ('gt', 'gt'),
#  ('gt', 'really'),
#  ('really', 'future'),
#  ('future', 'network'),
#  ('network', 'data'),
#  ('data', 'may'),
#  ('may', 'win'),
#  ('win', 'long'),
#  ('long', 'term'),
#  ('term', 'us'),
#  ('us', 'tv'),
#  ('tv', 'room'),
#  ('room', 'nobody'),
#  ('nobody', 'raise'),
#  ('raise', 'hand'),
#  ('hand', 'packed'),
#  ('packed', 'room'),
#  ('room', 'session'),
#  ('session', 'overload'),
#  ('overload', 'info'),
#  ('info', 'delivered'),
#  ('delivered', 'kill'),
#  ('kill', 'discovery'),
#  ('discovery', 'say'),
#  ('say', 'ppl'),
#  ('ppl', 'lose'),
#  ('lose', 'curiosity'),
#  ('curiosity', 'wonder'),
#  ('wonder', 'need'),
#  ('need', 'serendipity'),
#  ('serendipity', 'damn'),
#  ('damn', 'glow'),
#  ('glow', 'dark'),
#  ('dark', 'cup'),
#  ('cup', 'leaked'),
#  ('leaked', 'glow'),
#  ('glow', 'dark'),
#  ('dark', 'goo'),
#  ('goo', 'camera'),
#  ('camera', 'bag'),
#  ('bag', 'dropped'),
#  ('dropped', 'real'),
#  ('real', 'estate'),
#  ('estate', 'search'),
#  ('search', 'right'),
#  ('right', 'need'),
#  ('need', 'invest'),
#  ('invest', 'much'),
#  ('much', 'willing'),
#  ('willing', 'moment'),
#  ('moment', 'looking'),
#  ('looking', 'forward'),
#  ('forward', 'day'),
#  ('day', 'release'),
#  ('release', 'native'),
#  ('native', 'tablet'),
#  ('tablet', 'optimized'),
#  ('optimized', 'client'),
#  ...]

# %% [markdown]
# ###### Modelling dataframe

# %%
# df_model = df[df_negative['Company_Product'] == 'Google Products']
df.columns
# Out:
# Index(['tweet_text', 'clean_tweet_text', 'Tweet_Directed_at',
#        'is_there_an_emotion_directed_at_a_brand_or_product', 'Company_Product',
#        'text_tokenized', 'text_tokenized_lemmatized'],
#       dtype='object')

# %%
df.head(1)
# Out:
#                                                                                                                         tweet_text  \
# 0  .@wesley83 i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
#
#                                                                                        clean_tweet_text  \
# 0   i have a 3g iphone. after 3 hrs tweeting at , it was dead!  i need to upgrade. plugin stations at .
#
#   Tweet_Directed_at is_there_an_emotion_directed_at_a_brand_or_product  \
# 0            iPhone                                           Negative
#
#   Company_Product  \
# 0  Apple Products
#
#                                                    text_tokenized  \
# 0  [iphone, hrs, tweeting, dead, need, upgrade, plugin, stations]
#
#                                       text_tokenized_lemmatized
# 0  [iphone, hr, tweeting, dead, need, upgrade, plugin, station]

# %% [markdown]
# ### Modelling
#
# 1. perform baseline model(supervised): logistic regression/ multinomial naive bayes
# 2. Unsupervised
#
# * Filter the dataframe to access only the 'is_there_an_emotion_directed_at_a_brand_or_product' and the 'text_tokenized_lemmatized' column. For binary classification, only filter for postive and negative emotions. The 'text_tokenized_lemmatized' column must be converted back to a sentence to allow for TF-IDF vectorization.
# * Label encode the emotions column by assigning positive as 1 and negative as 0, the target column and then proceed to clustering/ modelling.Train a baseline model and evaluate its performance against project's metrics of success. Perform hyperparametrs tuning and try other unsupervised learning models.
#
#                  Clustering/Kmeans/SVM
# Binary: Positive & Negative
# Multiclass: Positive & Negative & Netral

# %% [markdown]
# ###### 1. Filtering the data frame columns of interest.

# %%
df_model =df[['is_there_an_emotion_directed_at_a_brand_or_product','text_tokenized_lemmatized','Company_Product']]
# Rename the columns
df_model.columns = ['Emotion','text_tokenized_lemmatized','Company_Product']
# Display the data frame
df_model
# Out:
#        Emotion  \
# 0     Negative
# 1     Positive
# 2     Positive
# 3     Negative
# 4     Positive
# ...        ...
# 7428   Neutral
# 7429  Positive
# 7430   Neutral
# 7431   Neutral
# 7432   Neutral
#
#                                                                                          text_tokenized_lemmatized  \
# 0                                                     [iphone, hr, tweeting, dead, need, upgrade, plugin, station]
# 1                            [know, awesome, ipad, iphone, app, likely, appreciate, design, also, giving, free, t]
# 2                                                                                               [wait, also, sale]
# 3                                                                [hope, year, festival, crashy, year, iphone, app]
# 4     [great, stuff, fri, marissa, mayer, google, tim, reilly, tech, book, conference, matt, mullenweg, wordpress]
# ...                                                                                                            ...
# 7428                                                               [yup, third, app, yet, android, suggestion, cc]
# 7429                                                                                            [ipad, everywhere]
# 7430     [google, zeiger, physician, never, reported, potential, ae, yet, fda, relies, physician, operating, data]
# 7431      [verizon, iphone, customer, complained, time, fell, back, hour, weekend, course, new, yorkers, attended]
# 7432                                                          [ïà, ü_, ââ, â_, ûârt, google, test, ûïcheck, offer]
#
#       Company_Product
# 0      Apple Products
# 1      Apple Products
# 2      Apple Products
# 3      Apple Products
# 4     Google Products
# ...               ...
# 7428  Google Products
# 7429   Apple Products
# 7430  Google Products
# 7431   Apple Products
# 7432  Google Products
#
# [7295 rows x 3 columns]

# %%
df_model = df_model[df_model['Emotion'] != 'Neutral']
df_model
# Out:
#        Emotion  \
# 0     Negative
# 1     Positive
# 2     Positive
# 3     Negative
# 4     Positive
# ...        ...
# 7420  Positive
# 7421  Positive
# 7422  Negative
# 7426  Positive
# 7429  Positive
#
#                                                                                          text_tokenized_lemmatized  \
# 0                                                     [iphone, hr, tweeting, dead, need, upgrade, plugin, station]
# 1                            [know, awesome, ipad, iphone, app, likely, appreciate, design, also, giving, free, t]
# 2                                                                                               [wait, also, sale]
# 3                                                                [hope, year, festival, crashy, year, iphone, app]
# 4     [great, stuff, fri, marissa, mayer, google, tim, reilly, tech, book, conference, matt, mullenweg, wordpress]
# ...                                                                                                            ...
# 7420                                                   [pr, guy, convinced, switch, back, iphone, great, coverage]
# 7421                                                               [papyrus, sort, like, ipad, nice, lol, lavelle]
# 7422                           [diller, say, google, tv, might, run, playstation, xbox, essentially, ready, today]
# 7426                  [always, used, camera, iphone, image, stabilizer, mode, suggestion, ipad, cam, app, feature]
# 7429                                                                                            [ipad, everywhere]
#
#       Company_Product
# 0      Apple Products
# 1      Apple Products
# 2      Apple Products
# 3      Apple Products
# 4     Google Products
# ...               ...
# 7420   Apple Products
# 7421   Apple Products
# 7422  Google Products
# 7426   Apple Products
# 7429   Apple Products
#
# [3411 rows x 3 columns]

# %%
df_model = df_model[df_model['Company_Product'] == 'Apple Products']
df_model
# Out:
#        Emotion  \
# 0     Negative
# 1     Positive
# 2     Positive
# 3     Negative
# 7     Positive
# ...        ...
# 7415  Positive
# 7420  Positive
# 7421  Positive
# 7426  Positive
# 7429  Positive
#
#                                                                          text_tokenized_lemmatized  \
# 0                                     [iphone, hr, tweeting, dead, need, upgrade, plugin, station]
# 1            [know, awesome, ipad, iphone, app, likely, appreciate, design, also, giving, free, t]
# 2                                                                               [wait, also, sale]
# 3                                                [hope, year, festival, crashy, year, iphone, app]
# 7                                             [beautifully, smart, simple, idea, wrote, ipad, app]
# ...                                                                                            ...
# 7415                                               [iphone, case, rad, ready, stop, tomorrow, get]
# 7420                                   [pr, guy, convinced, switch, back, iphone, great, coverage]
# 7421                                               [papyrus, sort, like, ipad, nice, lol, lavelle]
# 7426  [always, used, camera, iphone, image, stabilizer, mode, suggestion, ipad, cam, app, feature]
# 7429                                                                            [ipad, everywhere]
#
#      Company_Product
# 0     Apple Products
# 1     Apple Products
# 2     Apple Products
# 3     Apple Products
# 7     Apple Products
# ...              ...
# 7415  Apple Products
# 7420  Apple Products
# 7421  Apple Products
# 7426  Apple Products
# 7429  Apple Products
#
# [2463 rows x 3 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Preprocessing steps
def preprocess_data(df):
    # Converting the text_tokenized_lemmatized lists to text
    df['text_tokenized_lemmatized'] = df['text_tokenized_lemmatized'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
    
    # Encode emotion sentiment
    label_encoder = LabelEncoder()
    df['Emotion_encoded'] = label_encoder.fit_transform(df['Emotion'])
    
    # Binary classification preparation
    df = df[df['Emotion'] != 'Neutral']
    
    return df

# Prepare data
df_model = preprocess_data(df_model)
# Out:
# <ipython-input-525-b03b950e7cb5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_tokenized_lemmatized'] = df['text_tokenized_lemmatized'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
# <ipython-input-525-b03b950e7cb5>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Emotion_encoded'] = label_encoder.fit_transform(df['Emotion'])

# %%
df_model
# Out:
#        Emotion  \
# 0     Negative
# 1     Positive
# 2     Positive
# 3     Negative
# 7     Positive
# ...        ...
# 7415  Positive
# 7420  Positive
# 7421  Positive
# 7426  Positive
# 7429  Positive
#
#                                                             text_tokenized_lemmatized  \
# 0                                 iphone hr tweeting dead need upgrade plugin station
# 1            know awesome ipad iphone app likely appreciate design also giving free t
# 2                                                                      wait also sale
# 3                                           hope year festival crashy year iphone app
# 7                                        beautifully smart simple idea wrote ipad app
# ...                                                                               ...
# 7415                                          iphone case rad ready stop tomorrow get
# 7420                               pr guy convinced switch back iphone great coverage
# 7421                                          papyrus sort like ipad nice lol lavelle
# 7426  always used camera iphone image stabilizer mode suggestion ipad cam app feature
# 7429                                                                  ipad everywhere
#
#      Company_Product  Emotion_encoded
# 0     Apple Products                0
# 1     Apple Products                1
# 2     Apple Products                1
# 3     Apple Products                0
# 7     Apple Products                1
# ...              ...              ...
# 7415  Apple Products                1
# 7420  Apple Products                1
# 7421  Apple Products                1
# 7426  Apple Products                1
# 7429  Apple Products                1
#
# [2463 rows x 4 columns]

# %% [markdown]
# * You should split your dataset into training and testing sets before applying the TF-IDF transformer.
# *

# %%
df_model['text_tokenized_lemmatized'][0:20]
# Out:
# 0                                            iphone hr tweeting dead need upgrade plugin station
# 1                       know awesome ipad iphone app likely appreciate design also giving free t
# 2                                                                                 wait also sale
# 3                                                      hope year festival crashy year iphone app
# 7                                                   beautifully smart simple idea wrote ipad app
# 8                                 counting day plus strong canadian dollar mean stock apple gear
# 13                                                                                great ipad app
# 14                                                                   haha awesomely rad ipad app
# 16                     noticed dst coming weekend many iphone user hour late come sunday morning
# 17             added flight matching people plane airport also downloaded iphone app nicely done
# 18                                            must app lovely review forbes ipad app holler gram
# 19                                            need buy ipad2 austin sure need austin apple store
# 20                   oh god app ipad pure unadulterated awesome easier browse event ipad website
# 22                                                        photo installed iphone app really nice
# 24                        looking forward pre party wed hoping win resulting shameless promotion
# 25                                                               haha awesomely rad ipad app via
# 28                                                        smart ipad app may leave vuvuzela home
# 29                                                                           must app ipad going
# 34                                              best ha first line pop apple store event planner
# 37    great weather greet still need sweater night apple putting flash store downtown sell ipad2
# Name: text_tokenized_lemmatized, dtype: object

# %% [markdown]
# * The tfidf vectorizer returns sparse matrix. To reduce the dimensionality, implement the dimensionality algorithm that work well with the sparse matrices. for this case use Truncated SVD. It is a PCA like algorithm for sparse matrices. Parse in the n_components = 100 to retain as much of the explained variation.

# %%
df_model['text_tokenized_lemmatized']
# Out:
# 0                                   iphone hr tweeting dead need upgrade plugin station
# 1              know awesome ipad iphone app likely appreciate design also giving free t
# 2                                                                        wait also sale
# 3                                             hope year festival crashy year iphone app
# 7                                          beautifully smart simple idea wrote ipad app
#                                              ...
# 7415                                            iphone case rad ready stop tomorrow get
# 7420                                 pr guy convinced switch back iphone great coverage
# 7421                                            papyrus sort like ipad nice lol lavelle
# 7426    always used camera iphone image stabilizer mode suggestion ipad cam app feature
# 7429                                                                    ipad everywhere
# Name: text_tokenized_lemmatized, Length: 2463, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD

# %%
# Step 1: Convert the text data to TF-IDF features
vectorizer = TfidfVectorizer()
X_tfidf = vectorizer.fit_transform(df_model['text_tokenized_lemmatized'])

# X_tfidf is now a sparse matrix with TF-IDF features
print(X_tfidf.shape)  # Check the shape of the TF-IDF matrix
# Out:
# (2463, 3666)

# %%
# Step 2: Apply TruncatedSVD for dimensionality reduction
n_components = 100  # You can adjust this depending on how much reduction you want
svd = TruncatedSVD(n_components=n_components, random_state=42)
X_reduced = svd.fit_transform(X_tfidf)

# %% [markdown]
# ### Train the Clustering Model (KMeans)
# In this step, we’ll use the KMeans algorithm to cluster the data. Specify the number of clusters (n_clusters) and fit the model.

# %%
# Apply KMeans clustering on the TF-IDF data
from sklearn.cluster import KMeans

# Defining the number of clusters
n_clusters = 2 

kmeans = KMeans(n_clusters=n_clusters, random_state=42)
# Training the model
y_kmeans = kmeans.fit_predict(X_tfidf)

## Print the cluster assignments for each document
print(f"Cluster Assignments: {y_kmeans}")
# Out:
# Cluster Assignments: [0 0 0 ... 0 0 0]

# %% [markdown]
# ### Predict Cluster Assignments
# Once the model is trained, we can use it to predict the cluster assignment for each data point. These predictions are already generated by fit_predict().

# %%
# Step 3: Predict the cluster assignments for each document
predictions = kmeans.predict(X_tfidf)

# Print the predictions
print(f"Predicted Cluster Assignments: {predictions}")
# Out:
# Predicted Cluster Assignments: [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score

# Step 4: Evaluate the model using different metrics

# Inertia
print(f"Inertia: {kmeans.inertia_}")

# Silhouette Score (higher is better)
silhouette_avg = silhouette_score(X_tfidf, y_kmeans)
print(f"Silhouette Score: {silhouette_avg}")

# Davies-Bouldin Index (lower is better)
db_index = davies_bouldin_score(X_tfidf.toarray(), y_kmeans)
print(f"Davies-Bouldin Index: {db_index}")

from sklearn.metrics import adjusted_rand_score

ari = adjusted_rand_score(df_model['Emotion_encoded'], y_kmeans)
print(f"Adjusted Rand Index: {ari}")
# Out:
# Inertia: 2384.0109774576736
# Silhouette Score: 0.010731724919995985
# Davies-Bouldin Index: 7.045789639100911
# Adjusted Rand Index: -0.07072919885528518

# %% [markdown]
# ### Evaluating the model

# %%
from sklearn.metrics import homogeneity_score, completeness_score, v_measure_score

homogeneity = homogeneity_score(df_model['Emotion_encoded'], y_kmeans)
completeness = completeness_score(df_model['Emotion_encoded'], y_kmeans)
v_measure = v_measure_score(df_model['Emotion_encoded'], y_kmeans)

print(f"Homogeneity: {homogeneity}")
print(f"Completeness: {completeness}")
print(f"V-Measure: {v_measure}")
# Out:
# Homogeneity: 0.03968158888022029
# Completeness: 0.031922661221219006
# V-Measure: 0.03538175224929843

# %% [markdown]
# ### Visualize the Clusters
# Since the data is high-dimensional, it’s helpful to use dimensionality reduction to project the data to 2D for visualization. The tfidf vectorizer returns sparse matrix. To reduce the dimensionality, implement the dimensionality algorithm that work well with the sparse matrices. for this case use Truncated SVD. It is a PCA like algorithm for sparse matrices. Parse in the n_components = 100 to retain as much of the explained variation.

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Step 3: Apply PCA to reduce the data to 2D for visualization
pca = TruncatedSVD(n_components=90)
X_pca = pca.fit_transform(X_tfidf.toarray())  # Convert to dense array if sparse

# Step 4: Plot the clusters
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_kmeans, cmap='viridis', s=100, alpha=0.7)
plt.title(f'KMeans Clustering with {n_clusters} Clusters')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

# Optionally: Plot the cluster centers in the PCA space
centers = pca.transform(kmeans.cluster_centers_)
plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='x', s=200, label='Centroids')

plt.legend()
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.cluster.hierarchy as sch

# %%
# Step 1: Convert the text data to TF-IDF features
vectorizer = TfidfVectorizer()
X_tfidf = vectorizer.fit_transform(df_model['text_tokenized_lemmatized'])
# Step 2: Apply TruncatedSVD for dimensionality reduction 
n_components = 2  # Adjust the number of components
svd = TruncatedSVD(n_components=n_components, random_state=42)
X_reduced = svd.fit_transform(X_tfidf)

# %%
# Step 3: Perform Agglomerative Hierarchical Clustering
n_clusters = 2  # You can change this based on the desired number of clusters
agg_clust = AgglomerativeClustering(n_clusters=n_clusters, affinity='euclidean', linkage='ward')
y_agg_clust = agg_clust.fit_predict(X_reduced)

# %%
# Print the cluster assignments for each document
print(f"Cluster Assignments: {y_agg_clust}")
# Out:
# Cluster Assignments: [0 0 0 ... 0 0 0]

# %%
# This step helps visualize how the clusters are formed hierarchically.
plt.figure(figsize=(10, 7))
sch.dendrogram(sch.linkage(X_reduced, method='ward'))
plt.title("Dendrogram")
plt.xlabel("Documents")
plt.ylabel("Euclidean Distance")
plt.show()

# %%
from sklearn.metrics import silhouette_score

# Compute Silhouette Score
silhouette_avg = silhouette_score(X_reduced, y_agg_clust)
print(f"Silhouette Score: {silhouette_avg}")


from sklearn.metrics import davies_bouldin_score

# Compute Davies-Bouldin Index
db_index = davies_bouldin_score(X_reduced, y_agg_clust)
print(f"Davies-Bouldin Index: {db_index}")


from sklearn.metrics import normalized_mutual_info_score

# Assuming you have true labels (y_true)
nmi = normalized_mutual_info_score(df_model['Emotion_encoded'], y_agg_clust)
print(f"Normalized Mutual Information (NMI): {nmi}")
# Out:
# Silhouette Score: 0.8466784233393719
# Davies-Bouldin Index: 0.2035276182180148
# Normalized Mutual Information (NMI): 0.005809994846130175

# %% [markdown]
# * A Silhouette Score of 0.8467 is excellent! This means that your clusters are well-separated, and the points within each cluster are very cohesive. Clustering works really well in this case, and the data has clear boundaries between the clusters.
#
# * A DBI of 0.2035 is very good, as it suggests that the clusters are well-separated with very little overlap. The lower this value, the better the clustering
# * A NMI of 0.0058 is very low. This suggests that there is almost no correspondence between the true labels and the predicted clusters. In other words, the clusters found by your model do not reflect the actual class labels in the data, meaning that the true labels and clustering labels are not strongly related.

# %% [markdown]
# ##### Show the Cluster distribution

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Use PCA for dimensionality reduction to 2D
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_reduced)

# Scatter plot of the reduced data with cluster assignments
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_agg_clust, cmap='viridis')
plt.title("Cluster Visualization")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.show()

# %% [markdown]
# ##### Model Tuning
# * Experiment with different linkage methods.

# %%
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

# Try different linkage methods: 'ward', 'single', 'complete', 'average'
linkage_methods = ['ward', 'single', 'complete', 'average']

for method in linkage_methods:
    # Perform Agglomerative Hierarchical Clustering with each linkage method
    agg_clust = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage=method)
    y_agg_clust = agg_clust.fit_predict(X_reduced)  # Assuming X_reduced is your data

    # Plot the results to visualize the clusters
    plt.figure(figsize=(10, 7))
    plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y_agg_clust, cmap='viridis')
    plt.title(f"Hierarchical Clustering with {method} Linkage")
    plt.xlabel("PCA Component 1")
    plt.ylabel("PCA Component 2")
    plt.show()

# %%
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score

# Set a range of values for epsilon (eps) and min_samples to tune
eps_values = [0.1, 0.5, 1.0, 1.5]
min_samples_values = [5, 10, 15]

# Loop through different combinations of parameters and evaluate the results
for eps in eps_values:
    for min_samples in min_samples_values:
        # Initialize DBSCAN with current eps and min_samples
        dbscan = DBSCAN(eps=eps, min_samples=min_samples)
        
        # Fit DBSCAN on the data
        y_dbscan = dbscan.fit_predict(X_reduced)  # Assuming X_reduced is your data

        # Evaluate clustering performance with Silhouette Score
        if len(set(y_dbscan)) > 1:  # Avoid calculation if only one cluster is formed
            sil_score_dbscan = silhouette_score(X_reduced, y_dbscan)
            print(f"DBSCAN (eps={eps}, min_samples={min_samples}) Silhouette Score: {sil_score_dbscan}")
        
        # Plot the clusters for visual inspection
        plt.figure(figsize=(10, 7))
        plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y_dbscan, cmap='viridis')
        plt.title(f"DBSCAN Clustering (eps={eps}, min_samples={min_samples})")
        plt.xlabel("PCA Component 1")
        plt.ylabel("PCA Component 2")
        plt.show()
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score

# Set a range of values for epsilon (eps) and min_samples to tune
eps_values = [0.1, 0.5, 1.0, 1.5]
min_samples_values = [5, 10, 15]

# Loop through different combinations of parameters and evaluate the results
for eps in eps_values:
    for min_samples in min_samples_values:
        # Initialize DBSCAN with current eps and min_samples
        dbscan = DBSCAN(eps=eps, min_samples=min_samples)
        
        # Fit DBSCAN on the data
        y_dbscan = dbscan.fit_predict(X_reduced)  # Assuming X_reduced is your data

        # Evaluate clustering performance with Silhouette Score
        if len(set(y_dbscan)) > 1:  # Avoid calculation if only one cluster is formed
            sil_score_dbscan = silhouette_score(X_reduced, y_dbscan)
            print(f"DBSCAN (eps={eps}, min_samples={min_samples}) Silhouette Score: {sil_score_dbscan}")
        
        # Plot the clusters for visual inspection
        plt.figure(figsize=(10, 7))
        plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y_dbscan, cmap='viridis')
        plt.title(f"DBSCAN Clustering (eps={eps}, min_samples={min_samples})")
        plt.xlabel("PCA Component 1")
        plt.ylabel("PCA Component 2")
        plt.show()
# Out:
# DBSCAN (eps=0.1, min_samples=5) Silhouette Score: 0.784580880823078
# DBSCAN (eps=0.1, min_samples=10) Silhouette Score: 0.784580880823078
# DBSCAN (eps=0.1, min_samples=15) Silhouette Score: 0.784580880823078
# DBSCAN (eps=0.1, min_samples=5) Silhouette Score: 0.784580880823078
# DBSCAN (eps=0.1, min_samples=10) Silhouette Score: 0.784580880823078
# DBSCAN (eps=0.1, min_samples=15) Silhouette Score: 0.784580880823078
